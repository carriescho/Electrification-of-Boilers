# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tier_4 = pd.read_excel(r'C:\Users\zhang\Box\Boiler electrification potential\Tier4_CO2_emissions.xlsx')
C_1 = pd.read_excel(r'C:\Users\zhang\Box\Boiler electrification potential\C_1.xlsx')
C_2 = pd.read_excel(r'C:\Users\zhang\Box\Boiler electrification potential\C_2.xlsx')

# %%
# select data for boilers from Tier_4
b1 = []
b2 = []
b3 = []
b4 = []
b5 = []
b6 = []
b7 = []
b8 = []
b9 = []
b10 = []
b11 = []
b12 = []
b13 = []
b14 = []
b15 = []
b16 = []
b17 = []
b18 = []
b19 = []
b20 = []
b21 = []
b22 = []
b23 = []


#step 1: select all the information when the unit type contains "Boiler"
for i in range(len(tier_4)):
    a = 'Boiler'
    if a in str(tier_4.loc[i,'UNIT_TYPE']):
        a1 = tier_4.loc[i,'FACILITY_ID']
        a2 = tier_4.loc[i,'REPORTING_YEAR']
        a3 = tier_4.loc[i,'FACILITY_NAME']
        a4 = tier_4.loc[i,'UNIT_NAME']
        a5 = tier_4.loc[i,'UNIT_TYPE']
        a6 = tier_4.loc[i,'FUEL_TYPE']
        a7 = tier_4.loc[i,'FUEL_TYPE_OTHER']
        a8 = tier_4.loc[i,'FUEL_TYPE_BLEND']
        a9 = tier_4.loc[i,'COUNTY']
        a10 = tier_4.loc[i,'COUNTY_FIPS']
        a11 = tier_4.loc[i, 'NAICS']
        a12 = tier_4.loc[i, 'TIER4_FUEL_QUANTITY']
        a13 = tier_4.loc[i, 'TIER4_FUEL_QUANTITY_UOM']
        a14 = tier_4.loc[i, 'ANNUAL_HEAT_INPUT'] 
        a15 = tier_4.loc[i, 'ANNUAL_HEAT_INPUT_UOM'] 
        a16 = tier_4.loc[i, 'AGGR_HIGH_HEAT_CAPACITY']
        a17 = tier_4.loc[i, 'AGGR_HIGH_HEAT_CAPACITY_UOM']
        a18 = tier_4.loc[i, 'AGG_CUMULATIVE_HEAT_INPUTCAP']
        a19 = tier_4.loc[i, 'IND_UNIT_HEAT_INPUT_CAPACITY']
        a20 = tier_4.loc[i,'IND_UNIT_HEATINPUTCAPACITY_UOM']
        a21 = tier_4.loc[i,'IND_UNIT_HEATCAPACITY_UOM_OTHR']
        a22 = tier_4.loc[i,'T4_CH4_COMBUSTION_EMISSIONS']
        a23 = tier_4.loc[i,'T4_N2O_COMBUSTION_EMISSIONS']
        
        b1.append(a1)
        b2.append(a2)
        b3.append(a3)
        b4.append(a4)
        b5.append(a5)
        b6.append(a6)
        b7.append(a7)
        b8.append(a8)
        b9.append(a9)
        b10.append(a10)
        b11.append(a11)
        b12.append(a12)
        b13.append(a13)
        b14.append(a14)
        b15.append(a15)
        b16.append(a16)
        b17.append(a17)
        b18.append(a18)
        b19.append(a19)
        b20.append(a20)
        b21.append(a21)
        b22.append(a22)
        b23.append(a23)
        
# Step 2: select all the information when the unit name contains "Boilers" or "BLRS"
# But in this step, it may cause some duplicated entries with step 1 and we will do a group step in order to delete the duplicated entries
for j in range(len(tier_4)):
    y1 = 'Boilers'
    y2 = 'BLRS'
    y3 = 'Boiler'
    y4 = 'BOILER'
    y5 = 'FBB' #Fluid Bed Boiler
    y6 = 'PB' #Power Boiler
    y7 = 'CB' #Coal Boiler
    y8 = 'Blr' 
    y9 = 'boiler'
    
    if y1 in str(tier_4.loc[j,'UNIT_NAME']) or y2 in str(tier_4.loc[j,'UNIT_NAME']) or y3 in str(tier_4.loc[j,'UNIT_NAME']) or y4 in str(tier_4.loc[j,'UNIT_NAME']) or y5 in str(tier_4.loc[j,'UNIT_NAME']) or y6 in str(tier_4.loc[j,'UNIT_NAME']) or y7 in str(tier_4.loc[j,'UNIT_NAME']) or y8 in str(tier_4.loc[j,'UNIT_NAME']) or y9 in str(tier_4.loc[j,'UNIT_NAME']):
        aa1 = tier_4.loc[i,'FACILITY_ID']
        aa2 = tier_4.loc[i,'REPORTING_YEAR']
        aa3 = tier_4.loc[i,'FACILITY_NAME']
        aa4 = tier_4.loc[i,'UNIT_NAME']
        aa5 = tier_4.loc[i,'UNIT_TYPE']
        aa6 = tier_4.loc[i,'FUEL_TYPE']
        aa7 = tier_4.loc[i,'FUEL_TYPE_OTHER']
        aa8 = tier_4.loc[i,'FUEL_TYPE_BLEND']
        aa9 = tier_4.loc[i,'COUNTY']
        aa10 = tier_4.loc[i,'COUNTY_FIPS']
        aa11 = tier_4.loc[i, 'NAICS']
        aa12 = tier_4.loc[i, 'TIER4_FUEL_QUANTITY']
        aa13 = tier_4.loc[i, 'TIER4_FUEL_QUANTITY_UOM']
        aa14 = tier_4.loc[i, 'ANNUAL_HEAT_INPUT'] 
        aa15 = tier_4.loc[i, 'ANNUAL_HEAT_INPUT_UOM'] 
        aa16 = tier_4.loc[i, 'AGGR_HIGH_HEAT_CAPACITY']
        aa17 = tier_4.loc[i, 'AGGR_HIGH_HEAT_CAPACITY_UOM']
        aa18 = tier_4.loc[i, 'AGG_CUMULATIVE_HEAT_INPUTCAP']
        aa19 = tier_4.loc[i, 'IND_UNIT_HEAT_INPUT_CAPACITY']
        aa20 = tier_4.loc[i,'IND_UNIT_HEATINPUTCAPACITY_UOM']
        aa21 = tier_4.loc[i,'IND_UNIT_HEATCAPACITY_UOM_OTHR']
        aa22 = tier_4.loc[i,'T4_CH4_COMBUSTION_EMISSIONS']
        aa23 = tier_4.loc[i,'T4_N2O_COMBUSTION_EMISSIONS']
        
        b1.append(aa1)
        b2.append(aa2)
        b3.append(aa3)
        b4.append(aa4)
        b5.append(aa5)
        b6.append(aa6)
        b7.append(aa7)
        b8.append(aa8)
        b9.append(aa9)
        b10.append(aa10)
        b11.append(aa11)
        b12.append(aa12)
        b13.append(aa13)
        b14.append(aa14)
        b15.append(aa15)
        b16.append(aa16)
        b17.append(aa17)
        b18.append(aa18)
        b19.append(aa19)
        b20.append(aa20)
        b21.append(aa21)
        b22.append(aa22)
        b23.append(aa23)

# select the entries which the unit names are not clear, but in the same unit type it has "boiler" as its unit name
# according to the observation from 'boiler' file saved in 'Boiler electrification potential', the unit types include:
# CF, CH, HWH, MWC, OCS, OFB, PCO, PCT, PCWD, PCWW, PRH, PTO, and one blank entry
for k in range(len(tier_4)):
    #CF = 'CF (Cyclone Furnace)'#all unit names in cyclone furnace are boilers
    #CH = 'CH (Comfort heater)' # for the unit names that are not clear, it is assumed that they are comfort heaters
    #HWH = 'HWH (Heater  hot water)' # for the unit names which are numbers, they are water heaters instead of boilers, so it is not necessary to include all units in this unit type
    #MWC = 'MWC (Municipal waste combustor)'# for the unit names that are not clear, it is assumed they are municipal waste combustor
    #NGLH = 'NGLH (Heater  natural gas line)' #all unit names in NGLH are boilers
    OCS = 'OCS (Other combustion source)'#for those unit names are not clear, we don't know if they are boilers or not.
                                         #there are unit names that are clearly stated and are not boilers, and we should delete them from the database 
    #OFB = 'OFB (Fluidized bed  other)' #Unit name boiler and FBB (fluid bed boiler) should be accounted.
                                       #Other unit names are not counted as boilers
    #PCO = 'PCO (Pulverized coal  other)' #Unit names are clear in PCO
    #PCT = 'PCT (Pulverized coal  tangentially-fired)' #PB is power boiler. When unit names are PB and boilers, they are should be included
    #PCWD = 'PCWD (Pulverized coal  wall-fired  dry bottom)' #PB is power boiler, CB is coal boiler.
                                                            #Other unit names are not counted as boilers
    #PCWW = 'PCWW (Pulverized coal  wall-fired  wet bottom)' # unit names are all boilers
    #PRH = 'PRH (Process Heater)' #reboilers are heat exchangers typically used to provide heat to the bottom of industrial distillation columns and they are out of our scope.
                                #for those unit names that are not clearly stated, we assume they are process heaters
    #PTO = 'RTO (Regenerative thermal oxidizer)' #for thoses unit names that are not clearly stated, we assume they are egenerative thermal oxidizer
    #Blk = 'Blank' #for the unit names that are not clear, they should be heaters/incinerators when comparing with EPAGHGRP
    
    if OCS in str(tier_4.loc[k,'UNIT_TYPE']):
        v1 = tier_4.loc[i,'FACILITY_ID']
        v2 = tier_4.loc[i,'REPORTING_YEAR']
        v3 = tier_4.loc[i,'FACILITY_NAME']
        v4 = tier_4.loc[i,'UNIT_NAME']
        v5 = tier_4.loc[i,'UNIT_TYPE']
        v6 = tier_4.loc[i,'FUEL_TYPE']
        v7 = tier_4.loc[i,'FUEL_TYPE_OTHER']
        v8 = tier_4.loc[i,'FUEL_TYPE_BLEND']
        v9 = tier_4.loc[i,'COUNTY']
        v10 = tier_4.loc[i,'COUNTY_FIPS']
        v11 = tier_4.loc[i, 'NAICS']
        v12 = tier_4.loc[i, 'TIER4_FUEL_QUANTITY']
        v13 = tier_4.loc[i, 'TIER4_FUEL_QUANTITY_UOM']
        v14 = tier_4.loc[i, 'ANNUAL_HEAT_INPUT'] 
        v15 = tier_4.loc[i, 'ANNUAL_HEAT_INPUT_UOM'] 
        v16 = tier_4.loc[i, 'AGGR_HIGH_HEAT_CAPACITY']
        v17 = tier_4.loc[i, 'AGGR_HIGH_HEAT_CAPACITY_UOM']
        v18 = tier_4.loc[i, 'AGG_CUMULATIVE_HEAT_INPUTCAP']
        v19 = tier_4.loc[i, 'IND_UNIT_HEAT_INPUT_CAPACITY']
        v20 = tier_4.loc[i,'IND_UNIT_HEATINPUTCAPACITY_UOM']
        v21 = tier_4.loc[i,'IND_UNIT_HEATCAPACITY_UOM_OTHR']
        v22 = tier_4.loc[i,'T4_CH4_COMBUSTION_EMISSIONS']
        v23 = tier_4.loc[i,'T4_N2O_COMBUSTION_EMISSIONS']
        
        b1.append(v1)
        b2.append(v2)
        b3.append(v3)
        b4.append(v4)
        b5.append(v5)
        b6.append(v6)
        b7.append(v7)
        b8.append(v8)
        b9.append(v9)
        b10.append(v10)
        b11.append(v11)
        b12.append(v12)
        b13.append(v13)
        b14.append(v14)
        b15.append(v15)
        b16.append(v16)
        b17.append(v17)
        b18.append(v18)
        b19.append(v19)
        b20.append(v20)
        b21.append(v21)
        b22.append(v22)
        b23.append(v23)
        
f1=pd.DataFrame(columns=['FACILITY_ID','REPORTING_YEAR','FACILITY_NAME','UNIT_NAME','UNIT_TYPE','FUEL_TYPE','FUEL_TYPE_OTHER','FUEL_TYPE_BLEND','COUNTY','COUNTY_FIPS','NAICS', 'TIER4_FUEL_QUANTITY','TIER4_FUEL_QUANTITY_UOM', 'ANNUAL_HEAT_INPUT','ANNUAL_HEAT_INPUT_UOM','AGGR_HIGH_HEAT_CAPACITY', 'AGGR_HIGH_HEAT_CAPACITY_UOM', 'IND_UNIT_HEATCAPACITY_UOM_OTHR', 'T4_CH4_COMBUSTION_EMISSIONS', 'T4_N2O_COMBUSTION_EMISSIONS'])
                
f1['FACILITY_ID'] = b1
f1['REPORTING_YEAR'] = b2
f1['FACILITY_NAME'] = b3
f1['UNIT_NAME'] = b4
f1['UNIT_TYPE'] = b5
f1['FUEL_TYPE'] = b6
f1['FUEL_TYPE_OTHER'] = b7
f1['FUEL_TYPE_BLEND'] = b8
f1['COUNTY'] = b9
f1['COUNTY_FIPS'] = b10
f1['NAICS'] = b11
f1['TIER4_FUEL_QUANTITY'] = b12
f1['TIER4_FUEL_QUANTITY_UOM'] = b13
f1['ANNUAL_HEAT_INPUT'] = b14
f1['ANNUAL_HEAT_INPUT_UOM'] = b15
f1['AGGR_HIGH_HEAT_CAPACITY'] = b16
f1['AGGR_HIGH_HEAT_CAPACITY_UOM'] = b17
f1['AGG_CUMULATIVE_HEAT_INPUTCAP'] = b18
f1['IND_UNIT_HEAT_INPUT_CAPACITY'] = b19
f1['IND_UNIT_HEATINPUTCAPACITY_UOM'] = b20
f1['IND_UNIT_HEATCAPACITY_UOM_OTHR'] = b21
f1['T4_CH4_COMBUSTION_EMISSIONS'] = b22
f1['T4_N2O_COMBUSTION_EMISSIONS'] = b23

f2 = f1.drop_duplicates()

# %%
# convert EF data to dictionary
T1 = pd.DataFrame(C_1, columns = ['FUEL_TYPE', 'HHV', 'HHV_UNIT'])
T3 = pd.DataFrame(C_2, columns = ['FUEL_TYPE', 'EF_CH4'])
T4 = pd.DataFrame(C_2, columns = ['FUEL_TYPE', 'EF_N2O'])
T1['FUEL_TYPE'] = T1['FUEL_TYPE'].astype(str)
T3['FUEL_TYPE'] = T3['FUEL_TYPE'].astype(str)
T4['FUEL_TYPE'] = T4['FUEL_TYPE'].astype(str)
T1_hhv = T1.set_index('FUEL_TYPE')['HHV'].to_dict()
T3_ef = T3.set_index('FUEL_TYPE')['EF_CH4'].to_dict()
T4_ef = T4.set_index('FUEL_TYPE')['EF_N2O'].to_dict()

# %%
#remove /xa0 and space in the value of the dictionary
T1_hhv_res = {k.replace(u'\xa0', u''): v for k, v in T1_hhv.items() }
T3_ef_res = {k.replace(u'\xa0', u''): v for k, v in T3_ef.items() }
T4_ef_res = {k.replace(u'\xa0', u''): v for k, v in T4_ef.items() }

# %%
FUEL_UNIT = pd.read_excel(r'C:\Users\zhang\Box\Boiler electrification potential\FUEL_UNIT.xlsx')

# %%
FU = pd.DataFrame(FUEL_UNIT, columns = ['FUEL_TYPE','FUEL_COM_UNIT'])
FU_dict = FU.set_index('FUEL_TYPE')['FUEL_COM_UNIT'].to_dict()
FU_dict
# Out:
# {'Anthracite': 'short ton',
#  'Bituminous': 'short ton',
#  'Subbituminous': 'short ton',
#  'Lignite': 'short ton',
#  'Coal Coke': 'short ton',
#  'Mixed (Commercial sector)': 'short ton',
#  'Mixed (Industrial coking)': 'short ton',
#  'Mixed (Industrial sector)': 'short ton',
#  'Mixed (Electric Power sector)': 'short ton',
#  'Natural Gas (Weighted U.S. Average)': 'scf',
#  'Distillate Fuel Oil No. 1': 'gallon',
#  'Distillate Fuel Oil No. 2': 'gallon',
#  'Distillate Fuel Oil No. 4': 'gallon',
#  'Residual Fuel Oil No. 5': 'gallon',
#  'Residual Fuel Oil No. 6': 'gallon',
#  'Used Oil': 'gallon',
#  'Kerosene': 'gallon',
#  'Liquefied petroleum gases (LPG)\xa0': 'gallon',
#  'Propane\xa0': 'gallon',
#  'Propylene\xa0': 'gallon',
#  'Ethane\xa0': 'gallon',
#  'Ethanol': 'gallon',
#  'Ethylene\xa0': 'gallon',
#  'Isobutane\xa0': 'gallon',
#  'Isobutylene\xa0': 'gallon',
#  'Butane\xa0': 'gallon',
#  'Butylene\xa0': 'gallon',
#  'Naphtha (<401 deg F)': 'gallon',
# ...

# %%
# calculate fuel energy consumption
f3 = f2[(f2['ANNUAL_HEAT_INPUT'].notna()) & (f2['TIER4_FUEL_QUANTITY'].notna())] 
f3.loc[:,'Energy_consumption_MMBtu'] = f3.apply(lambda x: x['ANNUAL_HEAT_INPUT'], axis = 1)
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
f3
# Out:
#       FACILITY_ID  REPORTING_YEAR                FACILITY_NAME  \
# 1428      1001250            2014    MICHIGAN STATE UNIVERSITY
# 1429      1001250            2014    MICHIGAN STATE UNIVERSITY
# 1430      1001250            2014    MICHIGAN STATE UNIVERSITY
# 1431      1001250            2014    MICHIGAN STATE UNIVERSITY
# 1974      1004199            2017  Pixelle Specialty Solutions
# 1977      1004199            2017  Pixelle Specialty Solutions
#
#             UNIT_NAME                                UNIT_TYPE  \
# 1428           Unit 4  CFB (Boiler  circulating fluidized bed)
# 1429           Unit 4  CFB (Boiler  circulating fluidized bed)
# 1430           Unit 4  CFB (Boiler  circulating fluidized bed)
# 1431           Unit 4  CFB (Boiler  circulating fluidized bed)
# 1974  Power Boiler #5  CFB (Boiler  circulating fluidized bed)
# 1977  Power Boiler #5  CFB (Boiler  circulating fluidized bed)
#
#                                 FUEL_TYPE FUEL_TYPE_OTHER FUEL_TYPE_BLEND  \
# ...

# %%
k3 = f2[(f2['ANNUAL_HEAT_INPUT'].notna()) & (f2['TIER4_FUEL_QUANTITY'].isna())] 
k3.loc[:,'Energy_consumption_MMBtu'] = k3.apply(lambda x: x['ANNUAL_HEAT_INPUT'], axis = 1)
k3.loc[:,'TIER4_FUEL_QUANTITY'] = k3.apply(lambda x: x['Energy_consumption_MMBtu']/T1_hhv_res.get(x['FUEL_TYPE'],1), axis = 1)
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
k3
# Out:
#       FACILITY_ID  REPORTING_YEAR                           FACILITY_NAME  \
# 76        1000334            2014                             Tate & Lyle
# 77        1000334            2014                             Tate & Lyle
# 100       1000334            2014                             Tate & Lyle
# 101       1000334            2014                             Tate & Lyle
# 218       1000318            2014          Hopewell Cogeneration Facility
# ...           ...             ...                                     ...
# 3200      1005751            2017  AMERICAN CRYSTAL SUGAR - E GRAND FORKS
# 3203      1005751            2018  AMERICAN CRYSTAL SUGAR - E GRAND FORKS
# 3204      1005751            2018  AMERICAN CRYSTAL SUGAR - E GRAND FORKS
# 3209      1005751            2018  AMERICAN CRYSTAL SUGAR - E GRAND FORKS
# 3210      1005751            2018  AMERICAN CRYSTAL SUGAR - E GRAND FORKS
#
#                UNIT_NAME                                UNIT_TYPE  \
# ...

# %%
# when I check the data, I found when tier4_fuel_quantity is na, then annual heat input is na. As a result, we do not consider the situation when annual heat input is na, but fuel quantity is not na.

# %%
f4 = f2[(f2['ANNUAL_HEAT_INPUT'].isna()) & (f2['TIER4_FUEL_QUANTITY'].isna()) & (f2['T4_CH4_COMBUSTION_EMISSIONS'].notna())] 
f4.loc[:,'Energy_consumption_MMBtu'] = f4.apply(lambda x: x['T4_CH4_COMBUSTION_EMISSIONS']*1000/T3_ef_res.get(x['FUEL_TYPE'],1), axis = 1)
f4.loc[:,'TIER4_FUEL_QUANTITY'] = f4.apply(lambda x: x['Energy_consumption_MMBtu']/T1_hhv_res.get(x['FUEL_TYPE'],1), axis = 1)
f4['TIER4_FUEL_QUANTITY_UOM'] = f4['FUEL_TYPE'].map(FU_dict)
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\zhang\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
f4.FUEL_TYPE
# Out:
# 0                 NaN
# 1            Used Oil
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 3239    Subbituminous
# 3240    Subbituminous
# 3241    Subbituminous
# 3242    Subbituminous
# 3243    Subbituminous
# Name: FUEL_TYPE, Length: 2736, dtype: object

# %%
# the last condition : annual heat input is na, tier4 fuel quantity is na, and T4 CH4 combustion emission is na, then N2O emission must be na.
f5 = f2[(f2['ANNUAL_HEAT_INPUT'].isna()) & (f2['TIER4_FUEL_QUANTITY'].isna()) & (f2['T4_CH4_COMBUSTION_EMISSIONS'].isna())]

# %%
f5
# Out:
#       FACILITY_ID  REPORTING_YEAR                      FACILITY_NAME  \
# 859       1000401            2012                 Tate & Lyle-Loudon
# 862       1000401            2012                 Tate & Lyle-Loudon
# 1308      1000869            2012  KIMBERLY CLARK PA LLC/CHESTER OPR
# 1309      1000869            2012  KIMBERLY CLARK PA LLC/CHESTER OPR
# 1312      1000869            2013  KIMBERLY CLARK PA LLC/CHESTER OPR
# 1313      1000869            2013  KIMBERLY CLARK PA LLC/CHESTER OPR
# 1314      1000869            2013  KIMBERLY CLARK PA LLC/CHESTER OPR
# 1315      1000869            2013  KIMBERLY CLARK PA LLC/CHESTER OPR
# 1354      1003664            2012                       Hanford L.P.
# 1563      1005088            2013                     RIO BRAVO POSO
# 1564      1005088            2013                     RIO BRAVO POSO
#
#                     UNIT_NAME                                UNIT_TYPE  \
# ...

# %%
f6 = pd.concat([f3,k3, f4, f5])
f2 = f6

# %%
f2
# Out:
#       FACILITY_ID  REPORTING_YEAR                      FACILITY_NAME  \
# 1428      1001250            2014          MICHIGAN STATE UNIVERSITY
# 1429      1001250            2014          MICHIGAN STATE UNIVERSITY
# 1430      1001250            2014          MICHIGAN STATE UNIVERSITY
# 1431      1001250            2014          MICHIGAN STATE UNIVERSITY
# 1974      1004199            2017        Pixelle Specialty Solutions
# ...           ...             ...                                ...
# 1314      1000869            2013  KIMBERLY CLARK PA LLC/CHESTER OPR
# 1315      1000869            2013  KIMBERLY CLARK PA LLC/CHESTER OPR
# 1354      1003664            2012                       Hanford L.P.
# 1563      1005088            2013                     RIO BRAVO POSO
# 1564      1005088            2013                     RIO BRAVO POSO
#
#             UNIT_NAME                                UNIT_TYPE  \
# 1428           Unit 4  CFB (Boiler  circulating fluidized bed)
# ...

# %%
# fuel type classification

z1 = 'Distillate Fuel Oil No. 1'
z2 = 'Distillate Fuel Oil No. 2'
z3 = 'Distillate Fuel Oil No. 4'
z4 = 'Residual Fuel Oil No. 5'
z5 = 'Residual Fuel Oil No. 6'
z6  = 'Used Oil'
z7 = 'Kerosene'
z8 = 'Liquefied petroleum gases (LPG)'
z9 = 'Propane'
z10 = 'Propylene'
z11 = 'Ethane'
z12 = 'Ethanol'
z13 = 'Ethylene'
z14 = 'Isobutane'
z15 = 'Isobutylene'
z16 = 'Butane'
z17 = 'Butylene'
z18 = 'Naphtha (<401 deg F)'
z19 = 'Natural Gasoline'
z20 = 'Other Oil (>401 deg F)'
z21 = 'Pentanes Plus'
z22 = 'Petrochemical Feedstocks'
z23 = 'Special Naphtha'
z24 = 'Unfinished Oils'
z25 = 'Heavy Gas Oils'
z26 = 'Lubricants'
z27 = 'Motor Gasoline'
z28 = 'Aviation Gasoline'
z29 = 'Kerosene-Type Jet Fuel'
z30 = 'Asphalt and Road Oil'
z31 = 'Crude Oil'
z32 = 'Biodiesel (100%)'
z33 = 'Biodiesel'
z34 = 'Rendered Animal Fat'
z35 = 'Vegetable Oil'
z36 = 'Ethanol (100%)'
z37 = 'Natural Gas (Weighted U.S. Average)'
z38 = 'Propane Gas'
z39 = 'Blast Furnace Gas'
z40 = 'Coke Oven Gas'
z41 = 'Fuel Gas'
z42 = 'Landfill Gas'
z43 = 'Other Biomass Gases'
z44 = 'Biogas (Captured methane)'
z45 = 'Anthracite'
z46 = 'Bituminous'
z47 = 'Subbituminous'
z48 = 'Lignite'
z49 = 'Coal Coke'
z50 = 'Mixed (Commercial sector)'
z51 = 'Mixed (Industrial coking)'
z52 = 'Mixed (Industrial sector)'
z53= 'Mixed (Electric Power sector)'
z54 = 'Petroleum Coke'
z55 = 'Municipal Solid Waste'
z56 = 'Tires'
z57 = 'Plastics'
z58 = 'Wood and Wood Residuals'
z59 = 'Wood and Wood Residuals (dry basis) '
z60 = 'Agricultural Byproducts'
z61 = 'Peat'
z62 = 'Solid Byproducts'
z63 = 'Coke'

# %%
#groupby fuel type
f2_z1 = f2.loc[f2['FUEL_TYPE'] == z1]
f2_z2 = f2.loc[f2['FUEL_TYPE'] == z2]
f2_z3 = f2.loc[f2['FUEL_TYPE'] == z3]
f2_z4 = f2.loc[f2['FUEL_TYPE'] == z4]
f2_z5 = f2.loc[f2['FUEL_TYPE'] == z5]
f2_z6 = f2.loc[f2['FUEL_TYPE'] == z6]
f2_z7 = f2.loc[f2['FUEL_TYPE'] == z7]
f2_z8 = f2.loc[f2['FUEL_TYPE'] == z8]
f2_z9 = f2.loc[f2['FUEL_TYPE'] == z9]
f2_z10 = f2.loc[f2['FUEL_TYPE'] == z10]
f2_z11 = f2.loc[f2['FUEL_TYPE'] == z11]
f2_z12 = f2.loc[f2['FUEL_TYPE'] == z12]
f2_z13 = f2.loc[f2['FUEL_TYPE'] == z13]
f2_z14 = f2.loc[f2['FUEL_TYPE'] == z14]
f2_z15 = f2.loc[f2['FUEL_TYPE'] == z15]
f2_z16 = f2.loc[f2['FUEL_TYPE'] == z16]
f2_z17 = f2.loc[f2['FUEL_TYPE'] == z17]
f2_z18 = f2.loc[f2['FUEL_TYPE'] == z18]
f2_z19 = f2.loc[f2['FUEL_TYPE'] == z19]
f2_z20 = f2.loc[f2['FUEL_TYPE'] == z20]
f2_z21 = f2.loc[f2['FUEL_TYPE'] == z21]
f2_z22 = f2.loc[f2['FUEL_TYPE'] == z22]
f2_z23 = f2.loc[f2['FUEL_TYPE'] == z23]
f2_z24 = f2.loc[f2['FUEL_TYPE'] == z24]
f2_z25 = f2.loc[f2['FUEL_TYPE'] == z25]
f2_z26 = f2.loc[f2['FUEL_TYPE'] == z26]
f2_z27 = f2.loc[f2['FUEL_TYPE'] == z27]
f2_z28 = f2.loc[f2['FUEL_TYPE'] == z28]
f2_z29 = f2.loc[f2['FUEL_TYPE'] == z29]
f2_z30 = f2.loc[f2['FUEL_TYPE'] == z30]
f2_z31 = f2.loc[f2['FUEL_TYPE'] == z31]
f2_z32 = f2.loc[f2['FUEL_TYPE'] == z32]
f2_z33 = f2.loc[f2['FUEL_TYPE'] == z33]
f2_z34 = f2.loc[f2['FUEL_TYPE'] == z34]
f2_z35 = f2.loc[f2['FUEL_TYPE'] == z35]
f2_z36 = f2.loc[f2['FUEL_TYPE'] == z36]
f2_z37 = f2.loc[f2['FUEL_TYPE'] == z37]
f2_z38 = f2.loc[f2['FUEL_TYPE'] == z38]
f2_z39 = f2.loc[f2['FUEL_TYPE'] == z39]
f2_z40 = f2.loc[f2['FUEL_TYPE'] == z40]
f2_z41 = f2.loc[f2['FUEL_TYPE'] == z41]
f2_z42 = f2.loc[f2['FUEL_TYPE'] == z42]
f2_z43 = f2.loc[f2['FUEL_TYPE'] == z43]
f2_z44 = f2.loc[f2['FUEL_TYPE'] == z44]
f2_z45 = f2.loc[f2['FUEL_TYPE'] == z45]
f2_z46 = f2.loc[f2['FUEL_TYPE'] == z46]
f2_z47 = f2.loc[f2['FUEL_TYPE'] == z47]
f2_z48 = f2.loc[f2['FUEL_TYPE'] == z48]
f2_z49 = f2.loc[f2['FUEL_TYPE'] == z49]
f2_z50 = f2.loc[f2['FUEL_TYPE'] == z50]
f2_z51 = f2.loc[f2['FUEL_TYPE'] == z51]
f2_z52 = f2.loc[f2['FUEL_TYPE'] == z52]
f2_z53 = f2.loc[f2['FUEL_TYPE'] == z53]
f2_z54 = f2.loc[f2['FUEL_TYPE'] == z54]
f2_z55 = f2.loc[f2['FUEL_TYPE'] == z55]
f2_z56 = f2.loc[f2['FUEL_TYPE'] == z56]
f2_z57 = f2.loc[f2['FUEL_TYPE'] == z57]
f2_z58 = f2.loc[f2['FUEL_TYPE'] == z58]
f2_z59 = f2.loc[f2['FUEL_TYPE'] == z59]
f2_z60 = f2.loc[f2['FUEL_TYPE'] == z60]
f2_z61 = f2.loc[f2['FUEL_TYPE'] == z61]
f2_z62 = f2.loc[f2['FUEL_TYPE'] == z62]
f2_z63 = f2.loc[f2['FUEL_TYPE'] == z63]

# %%
# convert unit of input capacity to mmBtu per hr
Unit_other = pd.read_excel(r'C:\Users\zhang\Box\Boiler electrification potential\Unit_other_tier4_1.xlsx')

# %%
f2_z1_mmBtu = f2_z1.loc[(f2_z1['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z1['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z2_mmBtu = f2_z2.loc[(f2_z2['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z2['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z3_mmBtu = f2_z3.loc[(f2_z3['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z3['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z4_mmBtu = f2_z4.loc[(f2_z4['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z4['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z5_mmBtu = f2_z5.loc[(f2_z5['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z5['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z6_mmBtu = f2_z6.loc[(f2_z6['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z6['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z7_mmBtu = f2_z7.loc[(f2_z7['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z7['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z8_mmBtu = f2_z8.loc[(f2_z8['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z8['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z9_mmBtu = f2_z9.loc[(f2_z9['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z9['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z10_mmBtu = f2_z10.loc[(f2_z10['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z10['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z11_mmBtu = f2_z11.loc[(f2_z11['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z11['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z12_mmBtu = f2_z12.loc[(f2_z12['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z12['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z13_mmBtu = f2_z13.loc[(f2_z13['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z13['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z14_mmBtu = f2_z14.loc[(f2_z14['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z14['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z15_mmBtu = f2_z15.loc[(f2_z15['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z15['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z16_mmBtu = f2_z16.loc[(f2_z16['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z16['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z17_mmBtu = f2_z17.loc[(f2_z17['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z17['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z18_mmBtu = f2_z18.loc[(f2_z18['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z18['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z19_mmBtu = f2_z19.loc[(f2_z19['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z19['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z20_mmBtu = f2_z20.loc[(f2_z20['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z20['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z21_mmBtu = f2_z21.loc[(f2_z21['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z21['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z22_mmBtu = f2_z22.loc[(f2_z22['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z22['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z23_mmBtu = f2_z23.loc[(f2_z23['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z23['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z24_mmBtu = f2_z24.loc[(f2_z24['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z24['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z25_mmBtu = f2_z25.loc[(f2_z25['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z25['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z26_mmBtu = f2_z26.loc[(f2_z26['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z26['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z27_mmBtu = f2_z27.loc[(f2_z27['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z27['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z28_mmBtu = f2_z28.loc[(f2_z28['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z28['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z29_mmBtu = f2_z29.loc[(f2_z29['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z29['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z30_mmBtu = f2_z30.loc[(f2_z30['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z30['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z31_mmBtu = f2_z31.loc[(f2_z31['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z31['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z32_mmBtu = f2_z32.loc[(f2_z32['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z32['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z33_mmBtu = f2_z33.loc[(f2_z33['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z33['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z34_mmBtu = f2_z34.loc[(f2_z34['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z34['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z35_mmBtu = f2_z35.loc[(f2_z35['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z35['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z36_mmBtu = f2_z36.loc[(f2_z36['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z36['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z37_mmBtu = f2_z37.loc[(f2_z37['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z37['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z38_mmBtu = f2_z38.loc[(f2_z38['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z38['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z39_mmBtu = f2_z39.loc[(f2_z39['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z39['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z40_mmBtu = f2_z40.loc[(f2_z40['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z40['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z41_mmBtu = f2_z41.loc[(f2_z41['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z41['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z42_mmBtu = f2_z42.loc[(f2_z42['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z42['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z43_mmBtu = f2_z43.loc[(f2_z43['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z43['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z44_mmBtu = f2_z44.loc[(f2_z44['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z44['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z45_mmBtu = f2_z45.loc[(f2_z45['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z45['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z46_mmBtu = f2_z46.loc[(f2_z46['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z46['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z47_mmBtu = f2_z47.loc[(f2_z47['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z47['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z48_mmBtu = f2_z48.loc[(f2_z48['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z48['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z49_mmBtu = f2_z49.loc[(f2_z49['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z49['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z50_mmBtu = f2_z50.loc[(f2_z50['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z50['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z51_mmBtu = f2_z51.loc[(f2_z51['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z51['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z52_mmBtu = f2_z52.loc[(f2_z52['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z52['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z53_mmBtu = f2_z53.loc[(f2_z53['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z53['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z54_mmBtu = f2_z54.loc[(f2_z54['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z54['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z55_mmBtu = f2_z55.loc[(f2_z55['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z55['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z56_mmBtu = f2_z56.loc[(f2_z56['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z56['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z57_mmBtu = f2_z57.loc[(f2_z57['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z57['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z58_mmBtu = f2_z58.loc[(f2_z58['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z58['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z59_mmBtu = f2_z59.loc[(f2_z59['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z59['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z60_mmBtu = f2_z60.loc[(f2_z60['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z60['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z61_mmBtu = f2_z61.loc[(f2_z61['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z61['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z62_mmBtu = f2_z62.loc[(f2_z62['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z62['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f2_z63_mmBtu = f2_z63.loc[(f2_z63['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'mmBtu/hr')|(f2_z63['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
# convert unit of input capacity to mmBtu per hr
Unit_other['IND_UNIT_HEATCAPACITY_UOM_OTHR'] = Unit_other['IND_UNIT_HEATCAPACITY_UOM_OTHR'].astype(str)
Unit_other_z2 = Unit_other.set_index('IND_UNIT_HEATCAPACITY_UOM_OTHR')['Distillate Fuel Oil No. 2'].to_dict()
Unit_other_z6 = Unit_other.set_index('IND_UNIT_HEATCAPACITY_UOM_OTHR')['Used Oil'].to_dict()
Unit_other_z37 = Unit_other.set_index('IND_UNIT_HEATCAPACITY_UOM_OTHR')['Natural Gas (Weighted U.S. Average)'].to_dict()
Unit_other_z46 = Unit_other.set_index('IND_UNIT_HEATCAPACITY_UOM_OTHR')['Bituminous'].to_dict() 
Unit_other_z47 = Unit_other.set_index('IND_UNIT_HEATCAPACITY_UOM_OTHR')['Subbituminous'].to_dict()
Unit_other_z55 = Unit_other.set_index('IND_UNIT_HEATCAPACITY_UOM_OTHR')['Municipal Solid Waste'].to_dict()
Unit_other_z58 = Unit_other.set_index('IND_UNIT_HEATCAPACITY_UOM_OTHR')['Wood and Wood Residuals'].to_dict()

# %%
f2_z2_other = f2_z2.loc[(f2_z2['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'Other')]
f2_z2_other.loc[:,('IND_UNIT_HEAT_INPUT_CAPACITY')] = f2_z2_other.apply(lambda x: x[('IND_UNIT_HEAT_INPUT_CAPACITY')]*Unit_other_z2.get(x['IND_UNIT_HEATCAPACITY_UOM_OTHR'],0), axis = 1)  #units are mmBtu

f2_z6_other = f2_z6.loc[(f2_z6['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'Other')]
f2_z6_other.loc[:,('IND_UNIT_HEAT_INPUT_CAPACITY')] = f2_z6_other.apply(lambda x: x[('IND_UNIT_HEAT_INPUT_CAPACITY')]*Unit_other_z6.get(x['IND_UNIT_HEATCAPACITY_UOM_OTHR'],0), axis = 1)  #units are mmBtu

f2_z37_other = f2_z37.loc[(f2_z37['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'Other')]
f2_z37_other.loc[:,('IND_UNIT_HEAT_INPUT_CAPACITY')] = f2_z37_other.apply(lambda x: x[('IND_UNIT_HEAT_INPUT_CAPACITY')]*Unit_other_z37.get(x['IND_UNIT_HEATCAPACITY_UOM_OTHR'],0), axis = 1)  #units are mmBtu

f2_z46_other = f2_z46.loc[(f2_z46['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'Other')]
f2_z46_other.loc[:,('IND_UNIT_HEAT_INPUT_CAPACITY')] = f2_z46_other.apply(lambda x: x[('IND_UNIT_HEAT_INPUT_CAPACITY')]*Unit_other_z46.get(x['IND_UNIT_HEATCAPACITY_UOM_OTHR'],0), axis = 1)  #units are mmBtu

f2_z47_other = f2_z47.loc[(f2_z47['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'Other')]
f2_z47_other.loc[:,('IND_UNIT_HEAT_INPUT_CAPACITY')] = f2_z47_other.apply(lambda x: x[('IND_UNIT_HEAT_INPUT_CAPACITY')]*Unit_other_z47.get(x['IND_UNIT_HEATCAPACITY_UOM_OTHR'],0), axis = 1)  #units are mmBtu

f2_z55_other = f2_z55.loc[(f2_z55['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'Other')]
f2_z55_other.loc[:,('IND_UNIT_HEAT_INPUT_CAPACITY')] = f2_z55_other.apply(lambda x: x[('IND_UNIT_HEAT_INPUT_CAPACITY')]*Unit_other_z55.get(x['IND_UNIT_HEATCAPACITY_UOM_OTHR'],0), axis = 1)  #units are mmBtu

f2_z58_other = f2_z58.loc[(f2_z58['IND_UNIT_HEATINPUTCAPACITY_UOM'] == 'Other')]
f2_z58_other.loc[:,('IND_UNIT_HEAT_INPUT_CAPACITY')] = f2_z58_other.apply(lambda x: x[('IND_UNIT_HEAT_INPUT_CAPACITY')]*Unit_other_z58.get(x['IND_UNIT_HEATCAPACITY_UOM_OTHR'],0), axis = 1)  #units are mmBtu
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# concat mmBtu with units of others
f2_z2_tier4 = pd.concat([f2_z2_mmBtu,f2_z2_other])
f2_z6_tier4 = pd.concat([f2_z6_mmBtu,f2_z6_other])
f2_z37_tier4 = pd.concat([f2_z37_mmBtu,f2_z37_other])
f2_z46_tier4 = pd.concat([f2_z46_mmBtu,f2_z46_other])
f2_z47_tier4 = pd.concat([f2_z47_mmBtu,f2_z47_other])
f2_z55_tier4 = pd.concat([f2_z55_mmBtu,f2_z55_other])
f2_z58_tier4 = pd.concat([f2_z58_mmBtu,f2_z58_other])

# %%
# in order to find valid entries, we compare energy consumption (mmbtu/hr) with heat capacity (mmbtu/hr)
f2_z1.loc[:,'ENERGY_MMBtu_hr'] = f2_z1.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z2_tier4.loc[:,'ENERGY_MMBtu_hr'] = f2_z2_tier4.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z3.loc[:,'ENERGY_MMBtu_hr'] = f2_z3.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z4.loc[:,'ENERGY_MMBtu_hr'] = f2_z4.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z5.loc[:,'ENERGY_MMBtu_hr'] = f2_z5.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z6_tier4.loc[:,'ENERGY_MMBtu_hr'] = f2_z6_tier4.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z7.loc[:,'ENERGY_MMBtu_hr'] = f2_z7.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z8.loc[:,'ENERGY_MMBtu_hr'] = f2_z8.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z9.loc[:,'ENERGY_MMBtu_hr'] = f2_z9.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z10.loc[:,'ENERGY_MMBtu_hr'] = f2_z10.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z11.loc[:,'ENERGY_MMBtu_hr'] = f2_z11.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z12.loc[:,'ENERGY_MMBtu_hr'] = f2_z12.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z13.loc[:,'ENERGY_MMBtu_hr'] = f2_z13.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z14.loc[:,'ENERGY_MMBtu_hr'] = f2_z14.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z15.loc[:,'ENERGY_MMBtu_hr'] = f2_z15.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z16.loc[:,'ENERGY_MMBtu_hr'] = f2_z16.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z17.loc[:,'ENERGY_MMBtu_hr'] = f2_z17.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z18.loc[:,'ENERGY_MMBtu_hr'] = f2_z18.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z19.loc[:,'ENERGY_MMBtu_hr'] = f2_z19.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z20.loc[:,'ENERGY_MMBtu_hr'] = f2_z20.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z21.loc[:,'ENERGY_MMBtu_hr'] = f2_z21.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z22.loc[:,'ENERGY_MMBtu_hr'] = f2_z22.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z23.loc[:,'ENERGY_MMBtu_hr'] = f2_z23.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z24.loc[:,'ENERGY_MMBtu_hr'] = f2_z24.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z25.loc[:,'ENERGY_MMBtu_hr'] = f2_z25.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z26.loc[:,'ENERGY_MMBtu_hr'] = f2_z26.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z27.loc[:,'ENERGY_MMBtu_hr'] = f2_z27.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z28.loc[:,'ENERGY_MMBtu_hr'] = f2_z28.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z29.loc[:,'ENERGY_MMBtu_hr'] = f2_z29.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z30.loc[:,'ENERGY_MMBtu_hr'] = f2_z30.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z31.loc[:,'ENERGY_MMBtu_hr'] = f2_z31.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z32.loc[:,'ENERGY_MMBtu_hr'] = f2_z32.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z33.loc[:,'ENERGY_MMBtu_hr'] = f2_z33.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z34.loc[:,'ENERGY_MMBtu_hr'] = f2_z34.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z35.loc[:,'ENERGY_MMBtu_hr'] = f2_z35.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z36.loc[:,'ENERGY_MMBtu_hr'] = f2_z36.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z37_tier4.loc[:,'ENERGY_MMBtu_hr'] = f2_z37_tier4.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z38.loc[:,'ENERGY_MMBtu_hr'] = f2_z38.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z39.loc[:,'ENERGY_MMBtu_hr'] = f2_z39.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z40.loc[:,'ENERGY_MMBtu_hr'] = f2_z40.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z41.loc[:,'ENERGY_MMBtu_hr'] = f2_z41.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z42.loc[:,'ENERGY_MMBtu_hr'] = f2_z42.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z43.loc[:,'ENERGY_MMBtu_hr'] = f2_z43.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z44.loc[:,'ENERGY_MMBtu_hr'] = f2_z44.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z45.loc[:,'ENERGY_MMBtu_hr'] = f2_z45.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z46_tier4.loc[:,'ENERGY_MMBtu_hr'] = f2_z46_tier4.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z47_tier4.loc[:,'ENERGY_MMBtu_hr'] = f2_z47_tier4.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z48.loc[:,'ENERGY_MMBtu_hr'] = f2_z48.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z49.loc[:,'ENERGY_MMBtu_hr'] = f2_z49.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z50.loc[:,'ENERGY_MMBtu_hr'] = f2_z50.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z51.loc[:,'ENERGY_MMBtu_hr'] = f2_z51.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z52.loc[:,'ENERGY_MMBtu_hr'] = f2_z52.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z53.loc[:,'ENERGY_MMBtu_hr'] = f2_z53.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z54.loc[:,'ENERGY_MMBtu_hr'] = f2_z54.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z55_tier4.loc[:,'ENERGY_MMBtu_hr'] = f2_z55_tier4.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z56.loc[:,'ENERGY_MMBtu_hr'] = f2_z56.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z57.loc[:,'ENERGY_MMBtu_hr'] = f2_z57.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z58_tier4.loc[:,'ENERGY_MMBtu_hr'] = f2_z58_tier4.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z59.loc[:,'ENERGY_MMBtu_hr'] = f2_z59.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z60.loc[:,'ENERGY_MMBtu_hr'] = f2_z60.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z61.loc[:,'ENERGY_MMBtu_hr'] = f2_z61.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z62.loc[:,'ENERGY_MMBtu_hr'] = f2_z62.loc[:,'Energy_consumption_MMBtu']/365/24
f2_z63.loc[:,'ENERGY_MMBtu_hr'] = f2_z63.loc[:,'Energy_consumption_MMBtu']/365/24
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
#select the entries which the capacity is greater or equal to energy consumption (drop the entries which energy consumption > capacity)
f2_z1 = f2_z1[(f2_z1['ENERGY_MMBtu_hr']<=f2_z1['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z1['ENERGY_MMBtu_hr']<=f2_z1['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z2_tier4 = f2_z2_tier4[(f2_z2_tier4['ENERGY_MMBtu_hr']<=f2_z2_tier4['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z2_tier4['ENERGY_MMBtu_hr']<=f2_z2_tier4['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z3 = f2_z3[(f2_z3['ENERGY_MMBtu_hr']<=f2_z3['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z3['ENERGY_MMBtu_hr']<=f2_z3['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z4 = f2_z4[(f2_z4['ENERGY_MMBtu_hr']<=f2_z4['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z4['ENERGY_MMBtu_hr']<=f2_z4['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z5 = f2_z5[(f2_z5['ENERGY_MMBtu_hr']<=f2_z5['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z5['ENERGY_MMBtu_hr']<=f2_z5['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z6_tier4 = f2_z6_tier4[(f2_z6_tier4['ENERGY_MMBtu_hr']<=f2_z6_tier4['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z6_tier4['ENERGY_MMBtu_hr']<=f2_z6_tier4['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z7 = f2_z7[(f2_z7['ENERGY_MMBtu_hr']<=f2_z7['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z7['ENERGY_MMBtu_hr']<=f2_z7['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z8 = f2_z8[(f2_z8['ENERGY_MMBtu_hr']<=f2_z8['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z8['ENERGY_MMBtu_hr']<=f2_z8['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z9 = f2_z9[(f2_z9['ENERGY_MMBtu_hr']<=f2_z9['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z9['ENERGY_MMBtu_hr']<=f2_z9['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z10 = f2_z10[(f2_z10['ENERGY_MMBtu_hr']<=f2_z10['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z10['ENERGY_MMBtu_hr']<=f2_z10['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z11 = f2_z11[(f2_z11['ENERGY_MMBtu_hr']<=f2_z11['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z11['ENERGY_MMBtu_hr']<=f2_z11['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z12 = f2_z12[(f2_z12['ENERGY_MMBtu_hr']<=f2_z12['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z12['ENERGY_MMBtu_hr']<=f2_z12['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z13 = f2_z13[(f2_z13['ENERGY_MMBtu_hr']<=f2_z13['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z13['ENERGY_MMBtu_hr']<=f2_z13['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z14 = f2_z14[(f2_z14['ENERGY_MMBtu_hr']<=f2_z14['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z14['ENERGY_MMBtu_hr']<=f2_z14['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z15 = f2_z15[(f2_z15['ENERGY_MMBtu_hr']<=f2_z15['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z15['ENERGY_MMBtu_hr']<=f2_z15['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z16 = f2_z16[(f2_z16['ENERGY_MMBtu_hr']<=f2_z16['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z16['ENERGY_MMBtu_hr']<=f2_z16['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z17 = f2_z17[(f2_z17['ENERGY_MMBtu_hr']<=f2_z17['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z17['ENERGY_MMBtu_hr']<=f2_z17['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z18 = f2_z18[(f2_z18['ENERGY_MMBtu_hr']<=f2_z18['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z18['ENERGY_MMBtu_hr']<=f2_z18['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z19 = f2_z19[(f2_z19['ENERGY_MMBtu_hr']<=f2_z19['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z19['ENERGY_MMBtu_hr']<=f2_z19['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z20 = f2_z20[(f2_z20['ENERGY_MMBtu_hr']<=f2_z20['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z20['ENERGY_MMBtu_hr']<=f2_z20['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z21 = f2_z21[(f2_z21['ENERGY_MMBtu_hr']<=f2_z21['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z21['ENERGY_MMBtu_hr']<=f2_z21['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z22 = f2_z22[(f2_z22['ENERGY_MMBtu_hr']<=f2_z22['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z22['ENERGY_MMBtu_hr']<=f2_z22['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z23 = f2_z23[(f2_z23['ENERGY_MMBtu_hr']<=f2_z23['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z23['ENERGY_MMBtu_hr']<=f2_z23['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z24 = f2_z24[(f2_z24['ENERGY_MMBtu_hr']<=f2_z24['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z24['ENERGY_MMBtu_hr']<=f2_z24['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z25 = f2_z25[(f2_z25['ENERGY_MMBtu_hr']<=f2_z25['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z25['ENERGY_MMBtu_hr']<=f2_z25['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z26 = f2_z26[(f2_z26['ENERGY_MMBtu_hr']<=f2_z26['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z26['ENERGY_MMBtu_hr']<=f2_z26['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z27 = f2_z27[(f2_z27['ENERGY_MMBtu_hr']<=f2_z27['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z27['ENERGY_MMBtu_hr']<=f2_z27['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z28 = f2_z28[(f2_z28['ENERGY_MMBtu_hr']<=f2_z28['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z28['ENERGY_MMBtu_hr']<=f2_z28['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z29 = f2_z29[(f2_z29['ENERGY_MMBtu_hr']<=f2_z29['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z29['ENERGY_MMBtu_hr']<=f2_z29['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z30 = f2_z30[(f2_z30['ENERGY_MMBtu_hr']<=f2_z30['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z30['ENERGY_MMBtu_hr']<=f2_z30['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z31 = f2_z31[(f2_z31['ENERGY_MMBtu_hr']<=f2_z31['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z31['ENERGY_MMBtu_hr']<=f2_z31['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z32 = f2_z32[(f2_z32['ENERGY_MMBtu_hr']<=f2_z32['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z32['ENERGY_MMBtu_hr']<=f2_z32['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z33 = f2_z33[(f2_z33['ENERGY_MMBtu_hr']<=f2_z33['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z33['ENERGY_MMBtu_hr']<=f2_z33['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z34 = f2_z34[(f2_z34['ENERGY_MMBtu_hr']<=f2_z34['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z34['ENERGY_MMBtu_hr']<=f2_z34['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z35 = f2_z35[(f2_z35['ENERGY_MMBtu_hr']<=f2_z35['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z35['ENERGY_MMBtu_hr']<=f2_z35['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z36 = f2_z36[(f2_z36['ENERGY_MMBtu_hr']<=f2_z36['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z36['ENERGY_MMBtu_hr']<=f2_z36['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z37_tier4 = f2_z37_tier4[(f2_z37_tier4['ENERGY_MMBtu_hr']<=f2_z37_tier4['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z37_tier4['ENERGY_MMBtu_hr']<=f2_z37_tier4['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z38 = f2_z38[(f2_z38['ENERGY_MMBtu_hr']<=f2_z38['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z38['ENERGY_MMBtu_hr']<=f2_z38['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z39 = f2_z39[(f2_z39['ENERGY_MMBtu_hr']<=f2_z39['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z39['ENERGY_MMBtu_hr']<=f2_z39['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z40 = f2_z40[(f2_z40['ENERGY_MMBtu_hr']<=f2_z40['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z40['ENERGY_MMBtu_hr']<=f2_z40['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z41 = f2_z41[(f2_z41['ENERGY_MMBtu_hr']<=f2_z41['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z41['ENERGY_MMBtu_hr']<=f2_z41['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z42 = f2_z42[(f2_z42['ENERGY_MMBtu_hr']<=f2_z42['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z42['ENERGY_MMBtu_hr']<=f2_z42['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z43 = f2_z43[(f2_z43['ENERGY_MMBtu_hr']<=f2_z43['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z43['ENERGY_MMBtu_hr']<=f2_z43['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z44 = f2_z44[(f2_z44['ENERGY_MMBtu_hr']<=f2_z44['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z44['ENERGY_MMBtu_hr']<=f2_z44['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z45 = f2_z45[(f2_z45['ENERGY_MMBtu_hr']<=f2_z45['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z45['ENERGY_MMBtu_hr']<=f2_z45['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z46_tier4 = f2_z46_tier4[(f2_z46_tier4['ENERGY_MMBtu_hr']<=f2_z46_tier4['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z46_tier4['ENERGY_MMBtu_hr']<=f2_z46_tier4['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z47_tier4 = f2_z47_tier4[(f2_z47_tier4['ENERGY_MMBtu_hr']<=f2_z47_tier4['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z47_tier4['ENERGY_MMBtu_hr']<=f2_z47_tier4['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z48 = f2_z48[(f2_z48['ENERGY_MMBtu_hr']<=f2_z48['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z48['ENERGY_MMBtu_hr']<=f2_z48['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z49 = f2_z49[(f2_z49['ENERGY_MMBtu_hr']<=f2_z49['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z49['ENERGY_MMBtu_hr']<=f2_z49['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z50 = f2_z50[(f2_z50['ENERGY_MMBtu_hr']<=f2_z50['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z50['ENERGY_MMBtu_hr']<=f2_z50['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z51 = f2_z51[(f2_z51['ENERGY_MMBtu_hr']<=f2_z51['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z51['ENERGY_MMBtu_hr']<=f2_z51['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z52 = f2_z52[(f2_z52['ENERGY_MMBtu_hr']<=f2_z52['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z52['ENERGY_MMBtu_hr']<=f2_z52['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z53 = f2_z53[(f2_z53['ENERGY_MMBtu_hr']<=f2_z53['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z53['ENERGY_MMBtu_hr']<=f2_z53['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z54 = f2_z54[(f2_z54['ENERGY_MMBtu_hr']<=f2_z54['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z54['ENERGY_MMBtu_hr']<=f2_z54['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z55_tier4 = f2_z55_tier4[(f2_z55_tier4['ENERGY_MMBtu_hr']<=f2_z55_tier4['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z55_tier4['ENERGY_MMBtu_hr']<=f2_z55_tier4['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z56 = f2_z56[(f2_z56['ENERGY_MMBtu_hr']<=f2_z56['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z56['ENERGY_MMBtu_hr']<=f2_z56['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z57 = f2_z57[(f2_z57['ENERGY_MMBtu_hr']<=f2_z57['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z57['ENERGY_MMBtu_hr']<=f2_z57['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z58_tier4 = f2_z58_tier4[(f2_z58_tier4['ENERGY_MMBtu_hr']<=f2_z58_tier4['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z55_tier4['ENERGY_MMBtu_hr']<=f2_z55_tier4['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z59 = f2_z59[(f2_z59['ENERGY_MMBtu_hr']<=f2_z59['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z59['ENERGY_MMBtu_hr']<=f2_z59['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z60 = f2_z60[(f2_z60['ENERGY_MMBtu_hr']<=f2_z60['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z60['ENERGY_MMBtu_hr']<=f2_z60['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z61 = f2_z61[(f2_z61['ENERGY_MMBtu_hr']<=f2_z61['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z61['ENERGY_MMBtu_hr']<=f2_z61['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z62 = f2_z62[(f2_z62['ENERGY_MMBtu_hr']<=f2_z62['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z62['ENERGY_MMBtu_hr']<=f2_z62['IND_UNIT_HEAT_INPUT_CAPACITY'])]
f2_z63 = f2_z63[(f2_z63['ENERGY_MMBtu_hr']<=f2_z63['AGGR_HIGH_HEAT_CAPACITY'])|(f2_z63['ENERGY_MMBtu_hr']<=f2_z63['IND_UNIT_HEAT_INPUT_CAPACITY'])]
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
f2_overall = pd.concat([f2_z1,f2_z2_tier4,f2_z3,f2_z4,f2_z5,f2_z6_tier4,f2_z7,f2_z8,f2_z9,f2_z10,f2_z11,f2_z12,f2_z13,f2_z14,f2_z15,f2_z16,f2_z17,f2_z18,f2_z19,f2_z20,f2_z21,f2_z22,f2_z23,f2_z24,f2_z25,f2_z26,f2_z27,f2_z28,f2_z29,f2_z30,f2_z31,f2_z32,f2_z33,f2_z34,f2_z35,f2_z36,f2_z37_tier4,f2_z38,f2_z39,f2_z40,f2_z41,f2_z42,f2_z43,f2_z44,f2_z45,f2_z46_tier4,f2_z47_tier4,f2_z48,f2_z49,f2_z50,f2_z51,f2_z52,f2_z53,f2_z54,f2_z55_tier4,f2_z56,f2_z57,f2_z58_tier4,f2_z60,f2_z61,f2_z62,f2_z63])
f2_overall["IND_UNIT_HEATINPUTCAPACITY_UOM"]= f2_overall["IND_UNIT_HEATINPUTCAPACITY_UOM"].replace("Other", "mmBtu/hr")
f2_new = f2_overall.rename(columns={'IND_UNIT_HEAT_INPUT_CAPACITY': 'INPUT_HEAT_CAPACITY','IND_UNIT_HEATINPUTCAPACITY_UOM':'INPUT_HEAT_CAPACITY_UNIT','IND_UNIT_HEATCAPACITY_UOM_OTHR':'INPUT_HEAT_CAPACITY_UNIT_OTHER','T4_CH4_COMBUSTION_EMISSIONS':'CH4_COMBUSTION_EMISSIONS','T4_N2O_COMBUSTION_EMISSIONS':'N2O_COMBUSTION_EMISSIONS','TIER4_FUEL_QUANTITY_UOM':'FUEL_UNIT','TIER4_FUEL_QUANTITY':'FUEL_COM'})
f2_new.to_excel(r'C:\Users\zhang\Box\Boiler electrification potential\Tier_4_cleaned.xlsx', index = False)

# %%
# plot data
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f2_overall['IND_UNIT_HEAT_INPUT_CAPACITY'],f2_overall['ENERGY_MMBtu_hr'],s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f2_overall['AGGR_HIGH_HEAT_CAPACITY'],f2_overall['ENERGY_MMBtu_hr'],s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.xlabel('Input capacity (MMBtu/hr)')
plt.ylabel('Energy consumption (MMBtu/hr)')
plt.show()
