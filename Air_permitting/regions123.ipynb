# %%
import pandas as pd
import numpy as np

# %%
reg1 = pd.read_csv('Air_permitting/Region_1.csv',encoding= 'unicode_escape')

# %%
reg2 = pd.read_csv('Air_permitting/Region_2.csv',encoding= 'unicode_escape')
reg3 = pd.read_csv('Air_permitting/Region_3.csv',encoding= 'unicode_escape')

# %%
reg1.head()
# Out:
#                          FACILITY_NAME   NAICS     ZIP  FIPS  REPORTING_YEAR  \
# 0                    Allnex USA, Inc.   325211  6492.0   NaN          2016.0
# 1                    Allnex USA, Inc.   325211  6492.0   NaN          2016.0
# 2  Frito-Lay, Inc. - Dayville Facility  311919  6241.0   NaN          2018.0
# 3  Frito-Lay, Inc. - Dayville Facility  311919  6241.0   NaN          2018.0
# 4  Frito-Lay, Inc. - Dayville Facility  311919  6241.0   NaN          2018.0
#
#                                        UNIT_NAME    FUEL_TYPE FUEL_QUANTITY  \
# 0                                       Boiler 1        Oil 6       120,000
# 1                                       Boiler 3        Oil 6       2800000
# 2  Cleaver Brooks Delta 60 Watertube Boiler No.1  Natural gas           NaN
# 3  Cleaver Brooks Delta 60 Watertube Boiler No.2  Natural gas           NaN
# 4  Cleaver Brooks Delta 60 Watertube Boiler No.3  Natural gas           NaN
#
#   FUEL_QUANTITY_UOM  Input_Capacity      Unit
# ...

# %%
reg2.head()
# Out:
#               FACILITY_NAME  COUNTY_FIPS COUNTY    ZIP  NAICS     SIC  \
# 0           STEINWAY & SONS          NaN    NaN  11105    NaN  3931.0
# 1           STEINWAY & SONS          NaN    NaN  11105    NaN  3931.0
# 2             CHEMPRENE INC          NaN    NaN  12508    NaN  3052.0
# 3             CHEMPRENE INC          NaN    NaN  12508    NaN  3052.0
# 4  GLOBALFOUNDRIES US 2 LLC          NaN    NaN  12533    NaN  3471.0
#
#    Description  REPORTING_YEAR                  UNIT_NAME  \
# 0          NaN          2017.0                    FST-600
# 1          NaN          2017.0  Cleaver Brooks, SB600-600
# 2          NaN          2016.0                      00B01
# 3          NaN          2016.0                      00B02
# 4          NaN          2017.0                        NaN
#
#                         FUEL_TYPE  FUEL_QUANTITY  FUEL_QUANTITY_UOM  \
# 0  No. 2 fuel oil and natural gas            NaN                NaN
# ...

# %%
reg3.head()
# Out:
#                                        FACILITY_NAME    ZIP     NAICS  SIC  \
# 0  General Dynamics  Armament and Technical Prod...  24354  332311.0  NaN
# 1  General Dynamics  Armament and Technical Prod...  24354  332311.0  NaN
# 2            Vaughan-Bassett Furniture Company, Inc.  24333  337122.0  NaN
# 3            Vaughan-Bassett Furniture Company, Inc.  24333  337122.0  NaN
# 4            Vaughan-Bassett Furniture Company, Inc.  24333  337122.0  NaN
#
#    REPORTING_YEAR         UNIT_NAME                   FUEL_TYPE  \
# 0          2013.0  Cleaver Brook 18  Natural gas/distillate oil
# 1          2013.0  Cleaver Brook 19  Natural gas/distillate oil
# 2          2017.0              BS-1                   Wood/coal
# 3          2017.0              BS-2                   Wood/coal
# 4          2017.0              BS-3                   Wood/coal
#
#    FUEL_QUANTITY FUEL_QUANTITY_UOM Input_Capacity      Unit Installed_Year
# ...

# %%
va = reg3[(reg3.ZIP >20100) &(reg3.ZIP<26887)]

# %%
pa[pa.ZIP==19030]
# Out:
#      FACILITY_NAME    ZIP  NAICS   SIC  REPORTING_YEAR          UNIT_NAME  \
# 159  HEUCOTECH LTD  19030    NaN  2865          2020.0                NaN
# 232  US STEEL CORP  19030    NaN  3479          2019.0  GAL3 STEAM BOILER
#
#        FUEL_TYPE  FUEL_QUANTITY FUEL_QUANTITY_UOM Input_Capacity      Unit  \
# 159  Natural gas            NaN               NaN          0.663  MMBtu/hr
# 232  Natural gas            NaN               NaN           31.2  MMBtu/hr
#
#     Installed_Year
# 159            NaN
# 232            NaN

# %%
#va.FACILITY_NAME.unique()
#va[va.FACILITY_NAME=='Perdue Grain and Oilseed, LLC']
