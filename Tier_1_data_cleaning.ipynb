# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tier_1 = pd.read_csv(r'C:\Users\zhang\Box\Boiler electrification potential\Tier1_CO2_emissions.csv')
C_1 = pd.read_excel(r'C:\Users\zhang\Box\Boiler electrification potential\C_1.xlsx')

# %%
# first, to pick boiler usage
# criteria: (1) unit type contains boiler, (2) unit name contains boiler, (3) unit type which does not contain "boiler" but its unit name is not clear and other unit names in this type contain "boiler"
b1 = []
b2 = []
b3 = []
b4 = []
b5 = []
b6 = []
b7 = []
b8 = []
b9 = []
b10 = []
b11 = []
b12 = []
b13 = []
b14 = []
b15 = []
b16 = []
b17 = []
b18 = []
b19 = []
b20 = []
b21 = []
b22 = []

#step 1: select all the information when the unit type contains "Boiler"
for i in range(len(tier_1)):
    a = 'Boiler'
    if a in str(tier_1.loc[i,'UNIT_TYPE_x']):
        a1 = tier_1.loc[i,'FACILITY_ID']
        a2 = tier_1.loc[i,'REPORTING_YEAR']
        a3 = tier_1.loc[i,'FACILITY_NAME_x']
        a4 = tier_1.loc[i,'UNIT_NAME']
        a5 = tier_1.loc[i,'UNIT_TYPE_x']
        a6 = tier_1.loc[i,'FUEL_TYPE']
        a7 = tier_1.loc[i,'FUEL_TYPE_OTHER']
        a8 = tier_1.loc[i,'FUEL_TYPE_BLEND']
        a9 = tier_1.loc[i,'COUNTY']
        a10 = tier_1.loc[i,'COUNTY_FIPS']
        a11 = tier_1.loc[i, 'NAICS']
        a12 = tier_1.loc[i, 'TIER']
        a13 = tier_1.loc[i, 'CO2_COMBUSTION_EMISSIONS']
        a14 = tier_1.loc[i,'CH4_COMBUSTION_EMISSIONS']
        a15 = tier_1.loc[i, 'FUEL_QUANTITY']
        a16 = tier_1.loc[i, 'FUEL_QUANTITY_UOM']
        a17 = tier_1.loc[i, 'AGGR_HIGH_HEAT_CAPACITY']
        a18 = tier_1.loc[i, 'AGGR_HIGH_HEAT_CAPACITY_UOM']
        a19 = tier_1.loc[i, 'AGG_CUMULATIVE_HEAT_INPUTCAP']
        a20 = tier_1.loc[i, 'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEAT_INPUT_CAPACITY']
        a21 = tier_1.loc[i,'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEATINPUTCAPACITY_UOM']
        a22 = tier_1.loc[i,'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEATCAPACITY_UOM_OTHR']
        
        b1.append(a1)
        b2.append(a2)
        b3.append(a3)
        b4.append(a4)
        b5.append(a5)
        b6.append(a6)
        b7.append(a7)
        b8.append(a8)
        b9.append(a9)
        b10.append(a10)
        b11.append(a11)
        b12.append(a12)
        b13.append(a13)
        b14.append(a14)
        b15.append(a15)
        b16.append(a16)
        b17.append(a17)
        b18.append(a18)
        b19.append(a19)
        b20.append(a20)
        b21.append(a21)
        b22.append(a22)

# Step 2: select all the information when the unit name contains "Boilers" or "BLRS"
# But in this step, it may cause some duplicated entries with step 1 and we will do a group step in order to delete the duplicated entries
for j in range(len(tier_1)):
    y1 = 'Boilers'
    y2 = 'BLRS'
    y3 = 'Boiler'
    y4 = 'BOILER'
    y5 = 'FBB' #Fluid Bed Boiler
    y6 = 'PB' #Power Boiler
    y7 = 'CB' #Coal Boiler
    y8 = 'Blr' 
    y9 = 'boiler'
    
    if y1 in str(tier_1.loc[j,'UNIT_NAME']) or y2 in str(tier_1.loc[j,'UNIT_NAME']) or y3 in str(tier_1.loc[j,'UNIT_NAME']) or y4 in str(tier_1.loc[j,'UNIT_NAME']) or y5 in str(tier_1.loc[j,'UNIT_NAME']) or y6 in str(tier_1.loc[j,'UNIT_NAME']) or y7 in str(tier_1.loc[j,'UNIT_NAME']) or y8 in str(tier_1.loc[j,'UNIT_NAME']) or y9 in str(tier_1.loc[j,'UNIT_NAME']):
        aa1 = tier_1.loc[j,'FACILITY_ID']
        aa2 = tier_1.loc[j,'REPORTING_YEAR']
        aa3 = tier_1.loc[j,'FACILITY_NAME_x']
        aa4 = tier_1.loc[j,'UNIT_NAME']
        aa5 = tier_1.loc[j,'UNIT_TYPE_x']
        aa6 = tier_1.loc[j,'FUEL_TYPE']
        aa7 = tier_1.loc[j,'FUEL_TYPE_OTHER']
        aa8 = tier_1.loc[j,'FUEL_TYPE_BLEND']
        aa9 = tier_1.loc[j,'COUNTY']
        aa10 = tier_1.loc[j,'COUNTY_FIPS']
        aa11 = tier_1.loc[j, 'NAICS']
        aa12 = tier_1.loc[j, 'TIER']
        aa13 = tier_1.loc[j, 'CO2_COMBUSTION_EMISSIONS']
        aa14 = tier_1.loc[j,'CH4_COMBUSTION_EMISSIONS']
        aa15 = tier_1.loc[j, 'FUEL_QUANTITY']
        aa16 = tier_1.loc[j, 'FUEL_QUANTITY_UOM']
        aa17 = tier_1.loc[j, 'AGGR_HIGH_HEAT_CAPACITY']
        aa18 = tier_1.loc[j, 'AGGR_HIGH_HEAT_CAPACITY_UOM']
        aa19 = tier_1.loc[j, 'AGG_CUMULATIVE_HEAT_INPUTCAP']
        aa20 = tier_1.loc[j, 'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEAT_INPUT_CAPACITY']
        aa21 = tier_1.loc[j,'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEATINPUTCAPACITY_UOM']
        aa22 = tier_1.loc[j,'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEATCAPACITY_UOM_OTHR']
        
        b1.append(aa1)
        b2.append(aa2)
        b3.append(aa3)
        b4.append(aa4)
        b5.append(aa5)
        b6.append(aa6)
        b7.append(aa7)
        b8.append(aa8)
        b9.append(aa9)
        b10.append(aa10)
        b11.append(aa11)
        b12.append(aa12)
        b13.append(aa13)
        b14.append(aa14)
        b15.append(aa15)
        b16.append(aa16)
        b17.append(aa17)
        b18.append(aa18)
        b19.append(aa19)
        b20.append(aa20)
        b21.append(aa21)
        b22.append(aa22)
        
# select the entries which the unit names are not clear, but in the same unit type it has "boiler" as its unit name
# according to the observation from 'boiler' file saved in 'Boiler electrification potential', the unit types include:
# CF, CH, HWH, MWC, OCS, OFB, PCO, PCT, PCWD, PCWW, PRH, PTO, and one blank entry
for k in range(len(tier_1)):
    #CF = 'CF (Cyclone Furnace)'#all unit names in cyclone furnace are boilers
    #CH = 'CH (Comfort heater)' # for the unit names that are not clear, it is assumed that they are comfort heaters
    #HWH = 'HWH (Heater  hot water)' # for the unit names which are numbers, they are water heaters instead of boilers, so it is not necessary to include all units in this unit type
    #MWC = 'MWC (Municipal waste combustor)'# for the unit names that are not clear, it is assumed they are municipal waste combustor
    #NGLH = 'NGLH (Heater  natural gas line)' #all unit names in NGLH are boilers
    OCS = 'OCS (Other combustion source)'#for those unit names are not clear, we don't know if they are boilers or not.
                                         #there are unit names that are clearly stated and are not boilers, and we should delete them from the database 
    #OFB = 'OFB (Fluidized bed  other)' #Unit name boiler and FBB (fluid bed boiler) should be accounted.
                                       #Other unit names are not counted as boilers
    #PCO = 'PCO (Pulverized coal  other)' #Unit names are clear in PCO
    #PCT = 'PCT (Pulverized coal  tangentially-fired)' #PB is power boiler. When unit names are PB and boilers, they are should be included
    #PCWD = 'PCWD (Pulverized coal  wall-fired  dry bottom)' #PB is power boiler, CB is coal boiler.
                                                            #Other unit names are not counted as boilers
    #PCWW = 'PCWW (Pulverized coal  wall-fired  wet bottom)' # unit names are all boilers
    #PRH = 'PRH (Process Heater)' #reboilers are heat exchangers typically used to provide heat to the bottom of industrial distillation columns and they are out of our scope.
                                #for those unit names that are not clearly stated, we assume they are process heaters
    #PTO = 'RTO (Regenerative thermal oxidizer)' #for thoses unit names that are not clearly stated, we assume they are egenerative thermal oxidizer
    #Blk = 'Blank' #for the unit names that are not clear, they should be heaters/incinerators when comparing with EPAGHGRP
    
    if OCS in str(tier_1.loc[k,'UNIT_TYPE_x']):
        v1 = tier_1.loc[k,'FACILITY_ID']
        v2 = tier_1.loc[k,'REPORTING_YEAR']
        v3 = tier_1.loc[k,'FACILITY_NAME_x']
        v4 = tier_1.loc[k,'UNIT_NAME']
        v5 = tier_1.loc[k,'UNIT_TYPE_x']
        v6 = tier_1.loc[k,'FUEL_TYPE']
        v7 = tier_1.loc[k,'FUEL_TYPE_OTHER']
        v8 = tier_1.loc[k,'FUEL_TYPE_BLEND']
        v9 = tier_1.loc[k,'COUNTY']
        v10 = tier_1.loc[k,'COUNTY_FIPS']
        v11 = tier_1.loc[k, 'NAICS']
        v12 = tier_1.loc[k, 'TIER']
        v13 = tier_1.loc[k, 'CO2_COMBUSTION_EMISSIONS']
        v14 = tier_1.loc[k,'CH4_COMBUSTION_EMISSIONS']
        v15 = tier_1.loc[k, 'FUEL_QUANTITY']
        v16 = tier_1.loc[k, 'FUEL_QUANTITY_UOM']
        v17 = tier_1.loc[k, 'AGGR_HIGH_HEAT_CAPACITY']
        v18 = tier_1.loc[k, 'AGGR_HIGH_HEAT_CAPACITY_UOM']
        v19 = tier_1.loc[k, 'AGG_CUMULATIVE_HEAT_INPUTCAP']
        v20 = tier_1.loc[k, 'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEAT_INPUT_CAPACITY']
        v21 = tier_1.loc[k,'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEATINPUTCAPACITY_UOM']
        v22 = tier_1.loc[k,'C_CONFIGURATION_LEVEL_INFO.IND_UNIT_HEATCAPACITY_UOM_OTHR']
        
        b1.append(v1)
        b2.append(v2)
        b3.append(v3)
        b4.append(v4)
        b5.append(v5)
        b6.append(v6)
        b7.append(v7)
        b8.append(v8)
        b9.append(v9)
        b10.append(v10)
        b11.append(v11)
        b12.append(v12)
        b13.append(v13)
        b14.append(v14)
        b15.append(v15)
        b16.append(v16)
        b17.append(v17)
        b18.append(v18)
        b19.append(v19)
        b20.append(v20)
        b21.append(v21)
        b22.append(v22)
    
f1=pd.DataFrame(columns=['FACILITY_ID','REPORTING_YEAR','FACILITY_NAME','UNIT_NAME','UNIT_TYPE','FUEL_TYPE','FUEL_TYPE_OTHER','FUEL_TYPE_BLEND','COUNTY','COUNTY_FIPS','NAICS','TIER','CO2_COMBUSTION_EMISSIONS','CH4_COMBUSTION_EMISSIONS','FUEL_QUANTITY','FUEL_QUANTITY_UOM','AGGR_HIGH_HEAT_CAPACITY','AGGR_HIGH_HEAT_CAPACITY_UOM','AGG_CUMULATIVE_HEAT_INPUTCAP','INPUT_HEAT_CAPACITY','INPUT_HEAT_CAPACITY_UNIT','INPUT_HEAT_CAPACITY_UNIT_OTHER'])
 
f1['FACILITY_ID'] = b1
f1['REPORTING_YEAR'] = b2
f1['FACILITY_NAME'] = b3
f1['UNIT_NAME'] = b4
f1['UNIT_TYPE'] = b5
f1['FUEL_TYPE'] = b6
f1['FUEL_TYPE_OTHER'] = b7
f1['FUEL_TYPE_BLEND'] = b8
f1['COUNTY'] = b9
f1['COUNTY_FIPS'] = b10
f1['NAICS'] = b11
f1['TIER'] = b12
f1['CO2_COMBUSTION_EMISSIONS'] = b13
f1['CH4_COMBUSTION_EMISSIONS'] = b14
f1['FUEL_QUANTITY'] = b15
f1['FUEL_QUANTITY_UOM'] = b16
f1['AGGR_HIGH_HEAT_CAPACITY'] = b17
f1['AGGR_HIGH_HEAT_CAPACITY_UOM'] = b18
f1['AGG_CUMULATIVE_HEAT_INPUTCAP'] = b19
f1['INPUT_HEAT_CAPACITY'] = b20
f1['INPUT_HEAT_CAPACITY_UNIT'] = b21
f1['INPUT_HEAT_CAPACITY_UNIT_OTHER'] = b22

f2 = f1.drop_duplicates()

# %%
f2
# Out:
#        FACILITY_ID  REPORTING_YEAR                         FACILITY_NAME  \
# 0          1005420            2012               COVE POINT LNG FACILITY
# 1          1005420            2012               COVE POINT LNG FACILITY
# 2          1005420            2011               COVE POINT LNG FACILITY
# 3          1005420            2011               COVE POINT LNG FACILITY
# 4          1010147            2015                Main Pass 61B Platform
# ...            ...             ...                                   ...
# 93147      1000505            2013           Indiantown Cogeneration  LP
# 93148      1005770            2014         AUX SABLE LIQUID PRODUCTS INC
# 93149      1005770            2014         AUX SABLE LIQUID PRODUCTS INC
# 93150      1002288            2011                    EVRAZ STRATCOR INC
# 93151      1013323            2018  Smithfield Fresh Meats Corp. Clinton
#
#                          UNIT_NAME                      UNIT_TYPE  \
# ...

# %%
#convert table c-1 from epaghgrp to dictionary
T1 = pd.DataFrame(C_1, columns = ['FUEL_TYPE', 'HHV', 'HHV_UNIT'])
T2 = pd.DataFrame(C_1, columns = ['FUEL_TYPE', 'EF', 'EF_UNIT'])

# %%
T1['FUEL_TYPE'] = T1['FUEL_TYPE'].astype(str)
T2['FUEL_TYPE'] = T2['FUEL_TYPE'].astype(str)

# %%
T1_hhv = T1.set_index('FUEL_TYPE')['HHV'].to_dict()
T2_ef = T2.set_index('FUEL_TYPE')['EF'].to_dict()

# %%
#remove /xa0 and space in the value of the dictionary
import re
replace = {v: re.sub(u'\xa0',u'', k) for k, v in T1_hhv.items()}
T1_hhv_res = dict((v,k) for k,v in replace.items())
replace1 = {v : re.sub(u'\xa0',u'', k) for k, v in T2_ef.items()}
T2_ef_res = dict((v,k) for k,v in replace1.items())

# %%
#update T1_hhv_res since after using re.sub function all the entries with same values disappear
T1_hhv_res.update( {'Coal Coke' : 24.8})
T1_hhv_res.update({'Coke': 24.8})
T1_hhv_res.update( {'Distillate Fuel Oil No. 1' : 0.139})
T1_hhv_res.update( {'Distillate Fuel Oil No. 2' : 0.138})
T1_hhv_res.update( {'Used Oil' : 0.138})
T1_hhv_res.update({'Kerosene': 0.135})
T1_hhv_res.update({'Propane': 0.135})
T1_hhv_res.update({'Ethanol': 0.084})
T1_hhv_res.update({'Isobutylene': 0.103})
T1_hhv_res.update({'Naphtha (<401 deg F)': 0.125})
T1_hhv_res.update({'Natural Gasoline': 0.11})
T1_hhv_res.update({'Other Oil (>401 deg F)': 0.139})
T1_hhv_res.update({'Petrochemical Feedstocks': 0.125})
T1_hhv_res.update({'Special Naphtha': 0.125})
T1_hhv_res.update({'Motor Gasoline': 0.125})
T1_hhv_res.update({'Aviation Gasoline': 0.12})
T1_hhv_res.update({'Wood and Wood Residuals (dry basis)': 17.48})
T1_hhv_res.update({'Other Biomass Gases': 0.000655})
T1_hhv_res.update({'Biodiesel (100%)': 0.128})

# %%
#update T2_ef_res
T2_ef_res.update( {'Coal Coke' : 113.67} )
T2_ef_res.update( {'Coke' : 113.67} )
T2_ef_res.update( {'Unfinished Oils' : 74.54} )
T2_ef_res.update( {'Wood and Wood Residuals (dry basis)' : 93.8} )
T2_ef_res.update( {'Landfill Gas' : 52.07} )
T2_ef_res.update( {'Other Biomass Gases' : 52.07})
T2_ef_res.update( {'Biodiesel (100%)' : 73.84})  
T2_ef_res.update( {'Ethanol' : 68.44})

# %%
#when fuel quantity has no data, calculating fuel consumption from CO2 emissions withh fuel type
f3 = f2[f2.loc[:,('FUEL_QUANTITY')].isnull()]
f3.CO2_COMBUSTION_EMISSIONS[f3.loc[:,('CO2_COMBUSTION_EMISSIONS')].isnull()] == 0
f3.loc[:,('ENERGY_COM')] = f3.apply(lambda x: x['CO2_COMBUSTION_EMISSIONS']/T2_ef_res.get(x['FUEL_TYPE'],1)*1000, axis =1) #when there is not data for fuel type, the ef is set to default 1
f3.loc[:,('FUEL_COM')]=f3.apply(lambda x: x['ENERGY_COM']/T1_hhv_res.get(x['FUEL_TYPE'],1), axis = 1)
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# it is weird that the fuel type blend is not included in the calculation method and I am not sure how to calculate it now
f6 = f3[f3['FUEL_TYPE_BLEND'].notna()] #calculate this when finding the correct method

# %%
#when there is data in fuel quantity, we use the data from fuel quantity
f4 = f2[f2[('FUEL_QUANTITY')].notna()]
f4.loc[:,('FUEL_COM')] = f4.apply(lambda x: x[('FUEL_QUANTITY')], axis = 1)
f4.loc[:,('FUEL_UNIT')] = f4.apply(lambda x: x[('FUEL_QUANTITY_UOM')],axis = 1)
f4.loc[:,('ENERGY_COM')] = f4.apply(lambda x: x[('FUEL_QUANTITY')]*T1_hhv_res.get(x['FUEL_TYPE'],0), axis = 1) #Unit are mmBtu
f4.loc[:,('ENERGY_UNIT')] = 'MMBtu'
f4.loc[:,('FUEL_UNIT')] = f4.loc[:,('FUEL_UNIT')].replace('scf/year','scf')
f4.loc[:,('FUEL_UNIT')] = f4.loc[:,('FUEL_UNIT')].replace('gallons/year','gallons')
f4.loc[:,('FUEL_UNIT')] = f4.loc[:,('FUEL_UNIT')].replace('short tons/year','tons')

# %%
 #if pd.isnull(f2.loc[l,('FUEL_QUANTITY')]) == True and pd.isnull(f2.loc[l,('CO2_COMBUSTION_EMISSIONS')]) == True:
        #print('NA')
#if pd.isnull(f2.loc[l,('FUEL_QUANTITY')]) == True and pd.isnull(f2.loc[l,('CO2_COMBUSTION_EMISSIONS')]) == False:
        #f2.loc[:,('Energy_COM')] = f2.apply(lambda x: x['CO2_COMBUSTION_EMISSIONS']/T2_ef_res.get(x['FUEL_TYPE'],1)*1000
    #if pd.isnull(f2.loc[l,('FUEL_QUANTITY')]) == True and pd.isnull(f2.loc[l,('CO2_COMBUSTION_EMISSIONS')]) == True:
        #print('NA')                                 
    #if pd.isnull(f2.loc[l,('FUEL_QUANTITY')]) == True and f2.loc[l,('TIER')] == 'Tier 1 (Equation C-1)':
        #f2.loc[:,('FUEL_COM')] = f2.apply(lambda x: x['CO2_COMBUSTION_EMISSIONS']/(T1_hhv_res.get(x['FUEL_TYPE'],1)/T2_ef_res.get(x['FUEL_TYPE'],1)*1000), axis = 1)      
    #if pd.isnull(f2.loc[l,('FUEL_QUANTITY')]) == True and f2.loc[l,('TIER')] == 'Tier 1 (Equation C-1a  natural gas billing in therms)':
        #f2.loc[:,('FUEL_COM')] = f2.apply(lambda x: x['CO2_COMBUSTION_EMISSIONS']/T2_ef_res.get(x['FUEL_TYPE'],1)*1000, axis = 1) # Unit is mmBtu instead of therms
    #if pd.isnull(f2.loc[l,('FUEL_QUANTITY')]) == True and f2.loc[l,('TIER')] == 'Tier 1 (Equation C-1b  natural gas billing in mmBtu)':
        #f2.loc[:,('FUEL_COM')] = f2.apply(lambda x: x['CO2_COMBUSTION_EMISSIONS']/T2_ef_res.get(x['FUEL_TYPE'],1)*1000, axis = 1) # Unit is mmBtu
    #if pd.isnull(f2.loc[l,('FUEL_QUANTITY')]) == True and pd.isnull(f2.loc[l,('CO2_COMBUSTION_EMISSIONS')]) == True:
        #print('NA')

# %%
#fill the units for f3
# unit with gallons
z1 = 'Distillate Fuel Oil No. 1'
z2 = 'Distillate Fuel Oil No. 2'
z3 = 'Distillate Fuel Oil No. 4'
z4 = 'Residual Fuel Oil No. 5'
z5 = 'Residual Fuel Oil No. 6'
z6  = 'Used Oil'
z7 = 'Kerosene'
z8 = 'Liquefied petroleum gases (LPG)'
z9 = 'Propane'
z10 = 'Propylene'
z11 = 'Ethane'
z12 = 'Ethanol'
z13 = 'Ethylene'
z14 = 'Isobutane'
z15 = 'Isobutylene'
z16 = 'Butane'
z17 = 'Butylene'
z18 = 'Naphtha (<401 deg F)'
z19 = 'Natural Gasoline'
z20 = 'Other Oil (>401 deg F)'
z21 = 'Pentanes Plus'
z22 = 'Petrochemical Feedstocks'
z23 = 'Special Naphtha'
z24 = 'Unfinished Oils'
z25 = 'Heavy Gas Oils'
z26 = 'Lubricants'
z27 = 'Motor Gasoline'
z28 = 'Aviation Gasoline'
z29 = 'Kerosene-Type Jet Fuel'
z30 = 'Asphalt and Road Oil'
z31 = 'Crude Oil'
z32 = 'Biodiesel (100%)'
z33 = 'Biodiesel'
z34 = 'Rendered Animal Fat'
z35 = 'Vegetable Oil'
z36 = 'Ethanol (100%)'

w1 = f3.loc[(f3['FUEL_TYPE'] == z1) | (f3['FUEL_TYPE'] == z2) | (f3['FUEL_TYPE'] == z3)| (f3['FUEL_TYPE'] == z4)| (f3['FUEL_TYPE'] == z5)| (f3['FUEL_TYPE'] == z6)| (f3['FUEL_TYPE'] == z7)| (f3['FUEL_TYPE'] == z8)| (f3['FUEL_TYPE'] == z9)| (f3['FUEL_TYPE'] == z10)| (f3['FUEL_TYPE'] == z11)| (f3['FUEL_TYPE'] == z12)| (f3['FUEL_TYPE'] == z13)| (f3['FUEL_TYPE'] == z14)| (f3['FUEL_TYPE'] == z15)| (f3['FUEL_TYPE'] == z16)| (f3['FUEL_TYPE'] == z17)| (f3['FUEL_TYPE'] == z18)| (f3['FUEL_TYPE'] == z19)| (f3['FUEL_TYPE'] == z20)| (f3['FUEL_TYPE'] == z21)| (f3['FUEL_TYPE'] == z22)| (f3['FUEL_TYPE'] == z23)| (f3['FUEL_TYPE'] == z24)| (f3['FUEL_TYPE'] == z25)| (f3['FUEL_TYPE'] == z26)| (f3['FUEL_TYPE'] == z27)| (f3['FUEL_TYPE'] == z28)| (f3['FUEL_TYPE'] == z29)| (f3['FUEL_TYPE'] == z30)| (f3['FUEL_TYPE'] == z31)| (f3['FUEL_TYPE'] == z32)| (f3['FUEL_TYPE'] == z33)| (f3['FUEL_TYPE'] == z34)| (f3['FUEL_TYPE'] == z35)| (f3['FUEL_TYPE'] == z36)]
w1.loc[:,('FUEL_UNIT')] = 'gallons'
w1.loc[:,('ENERGY_UNIT')] = 'MMBtu'

# %%
#unit with scf
z37 = 'Natural Gas (Weighted U.S. Average)'
z38 = 'Propane Gas'
z39 = 'Blast Furnace Gas'
z40 = 'Coke Oven Gas'
z41 = 'Fuel Gas'
z42 = 'Landfill Gas'
z43 = 'Other Biomass Gases'
z44 = 'Biogas (Captured methane)'

w2 = f3.loc[ (f3['FUEL_TYPE'] == z37)|(f3['FUEL_TYPE'] == z38)| (f3['FUEL_TYPE'] == z39)| (f3['FUEL_TYPE'] == z40)| (f3['FUEL_TYPE'] == z41)| (f3['FUEL_TYPE'] == z42)| (f3['FUEL_TYPE'] == z43)| (f3['FUEL_TYPE'] == z44)]
w2.loc[:,('FUEL_UNIT')] = 'scf'
w2.loc[:,('ENERGY_UNIT')] = 'MMBtu'

# %%
#unit with tons
z45 = 'Anthracite'
z46 = 'Bituminous'
z47 = 'Subbituminous'
z48 = 'Lignite'
z49 = 'Coal Coke'
z50 = 'Mixed (Commercial sector)'
z51 = 'Mixed (Industrial coking)'
z52 = 'Mixed (Industrial sector)'
z53= 'Mixed (Electric Power sector)'
z54 = 'Petroleum Coke'
z55 = 'Municipal Solid Waste'
z56 = 'Tires'
z57 = 'Plastics'
z58 = 'Wood and Wood Residuals'
z59 = 'Wood and Wood Residuals (dry basis)'
z60 = 'Agricultural Byproducts'
z61 = 'Peat'
z62 = 'Solid Byproducts'
z63 = 'Coke'

w3 = f3.loc[(f3['FUEL_TYPE'] == z45)|(f3['FUEL_TYPE'] == z46)|(f3['FUEL_TYPE'] == z47)|(f3['FUEL_TYPE'] == z48)|(f3['FUEL_TYPE'] == z49)|(f3['FUEL_TYPE'] == z50)|(f3['FUEL_TYPE'] == z51)|(f3['FUEL_TYPE'] == z52)|(f3['FUEL_TYPE'] == z53)|(f3['FUEL_TYPE'] == z54)|(f3['FUEL_TYPE'] == z55)|(f3['FUEL_TYPE'] == z56)|(f3['FUEL_TYPE'] == z57)|(f3['FUEL_TYPE'] == z58)|(f3['FUEL_TYPE'] == z59)|(f3['FUEL_TYPE'] == z60)|(f3['FUEL_TYPE'] == z61)|(f3['FUEL_TYPE'] == z62)|(f3['FUEL_TYPE'] == z63)]
w3.loc[:,('FUEL_UNIT')] = 'tons'
w3.loc[:,('ENERGY_UNIT')] = 'MMBtu'

# %%
w4 = f3[f3['FUEL_TYPE'].isnull()]
w4.loc[:,('FUEL_UNIT')] = ''
w4.loc[:,('ENERGY_UNIT')] = ''

# %%
f5 = pd.concat([w1,w2,w3,w4,f4]).reset_index()

# %%
f5 = f5[['FACILITY_ID','FACILITY_NAME','COUNTY_FIPS','COUNTY','NAICS','REPORTING_YEAR','UNIT_NAME','UNIT_TYPE','FUEL_TYPE','FUEL_TYPE_OTHER','FUEL_TYPE_BLEND','TIER','CO2_COMBUSTION_EMISSIONS','CH4_COMBUSTION_EMISSIONS','FUEL_QUANTITY','FUEL_QUANTITY_UOM','AGGR_HIGH_HEAT_CAPACITY','AGGR_HIGH_HEAT_CAPACITY_UOM','AGG_CUMULATIVE_HEAT_INPUTCAP','INPUT_HEAT_CAPACITY','INPUT_HEAT_CAPACITY_UNIT','INPUT_HEAT_CAPACITY_UNIT_OTHER','FUEL_COM','FUEL_UNIT','ENERGY_COM','ENERGY_UNIT']]

# %%
f5.to_csv(r'C:\Users\zhang\Box\Boiler electrification potential\Tier_1_cleaned.csv', index = False)

# %%
"""
capacity versus energy consumption (MMBtu)
remove the input heat capacity unit is "other"
"""
fig = plt.figure()
ax1 = fig.add_subplot(111)

f6 = f5.loc[(f5['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5[('AGGR_HIGH_HEAT_CAPACITY_UOM')] == 'mmBtu/hr')]
ax1.scatter(f6['INPUT_HEAT_CAPACITY'],f6['ENERGY_COM'])
ax1.scatter(f6['AGGR_HIGH_HEAT_CAPACITY'],f6['ENERGY_COM'])
plt.xlabel('Input capacity (MMBtu/hr)')
plt.ylabel('Energy consumption (MMBtu/yr)')
plt.show()


"""
the outlier (input capacity = 999999 mmBtu, energy consumption = 5.5E5 mmBtu happens at ABENGOA BIOENERGY CORPORATION COLWICH ETHANOL PLANT)
"""
# Out:
# '\nthe outlier (input capacity = 999999 mmBtu, energy consumption = 5.5E5 mmBtu happens at ABENGOA BIOENERGY CORPORATION COLWICH ETHANOL PLANT)\n'

# %%
Unit_other = pd.read_csv(r'C:\Users\zhang\Box\Boiler electrification potential\Unit_other_tier1.csv')

# %%
Unit_other['INPUT_HEAT_CAPACITY_UNIT_OTHER'] = Unit_other['INPUT_HEAT_CAPACITY_UNIT_OTHER'].astype(str)
Unit_other_z1 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Distillate Fuel Oil No. 1'].to_dict() 
Unit_other_z2 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Distillate Fuel Oil No. 2'].to_dict()
Unit_other_z3 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Distillate Fuel Oil No. 4'].to_dict()
Unit_other_z7 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Kerosene'].to_dict()
Unit_other_z8 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Liquefied petroleum gases (LPG)'].to_dict()
Unit_other_z27 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Motor Gasoline'].to_dict()
Unit_other_z37 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Natural Gas (Weighted U.S. Average)'].to_dict()
Unit_other_z9 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Propane'].to_dict()
Unit_other_z44 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Biogas (Captured methane)'].to_dict()
Unit_other_z4 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Residual Fuel Oil No. 5'].to_dict()
Unit_other_z6 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Used Oil'].to_dict()
Unit_other_z58 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Wood and Wood Residuals'].to_dict()
Unit_other_z59 = Unit_other.set_index('INPUT_HEAT_CAPACITY_UNIT_OTHER')['Wood and Wood Residuals'].to_dict() #wood and wood residuals (dry basis) and wood and wood residuals are the same

# %%
#groupby fuel type and plot
f5_z1 = f5.loc[f5['FUEL_TYPE'] == z1]
f5_z2 = f5.loc[f5['FUEL_TYPE'] == z2]
f5_z3 = f5.loc[f5['FUEL_TYPE'] == z3]
f5_z4 = f5.loc[f5['FUEL_TYPE'] == z4]
f5_z5 = f5.loc[f5['FUEL_TYPE'] == z5]
f5_z6 = f5.loc[f5['FUEL_TYPE'] == z6]
f5_z7 = f5.loc[f5['FUEL_TYPE'] == z7]
f5_z8 = f5.loc[f5['FUEL_TYPE'] == z8]
f5_z9 = f5.loc[f5['FUEL_TYPE'] == z9]
f5_z10 = f5.loc[f5['FUEL_TYPE'] == z10]
f5_z11 = f5.loc[f5['FUEL_TYPE'] == z11]
f5_z12 = f5.loc[f5['FUEL_TYPE'] == z12]
f5_z13 = f5.loc[f5['FUEL_TYPE'] == z13]
f5_z14 = f5.loc[f5['FUEL_TYPE'] == z14]
f5_z15 = f5.loc[f5['FUEL_TYPE'] == z15]
f5_z16 = f5.loc[f5['FUEL_TYPE'] == z16]
f5_z17 = f5.loc[f5['FUEL_TYPE'] == z17]
f5_z18 = f5.loc[f5['FUEL_TYPE'] == z18]
f5_z19 = f5.loc[f5['FUEL_TYPE'] == z19]
f5_z20 = f5.loc[f5['FUEL_TYPE'] == z20]
f5_z21 = f5.loc[f5['FUEL_TYPE'] == z21]
f5_z22 = f5.loc[f5['FUEL_TYPE'] == z22]
f5_z23 = f5.loc[f5['FUEL_TYPE'] == z23]
f5_z24 = f5.loc[f5['FUEL_TYPE'] == z24]
f5_z25 = f5.loc[f5['FUEL_TYPE'] == z25]
f5_z26 = f5.loc[f5['FUEL_TYPE'] == z26]
f5_z27 = f5.loc[f5['FUEL_TYPE'] == z27]
f5_z28 = f5.loc[f5['FUEL_TYPE'] == z28]
f5_z29 = f5.loc[f5['FUEL_TYPE'] == z29]
f5_z30 = f5.loc[f5['FUEL_TYPE'] == z30]
f5_z31 = f5.loc[f5['FUEL_TYPE'] == z31]
f5_z32 = f5.loc[f5['FUEL_TYPE'] == z32]
f5_z33 = f5.loc[f5['FUEL_TYPE'] == z33]
f5_z34 = f5.loc[f5['FUEL_TYPE'] == z34]
f5_z35 = f5.loc[f5['FUEL_TYPE'] == z35]
f5_z36 = f5.loc[f5['FUEL_TYPE'] == z36]
f5_z37 = f5.loc[f5['FUEL_TYPE'] == z37]
f5_z38 = f5.loc[f5['FUEL_TYPE'] == z38]
f5_z39 = f5.loc[f5['FUEL_TYPE'] == z39]
f5_z40 = f5.loc[f5['FUEL_TYPE'] == z40]
f5_z41 = f5.loc[f5['FUEL_TYPE'] == z41]
f5_z42 = f5.loc[f5['FUEL_TYPE'] == z42]
f5_z43 = f5.loc[f5['FUEL_TYPE'] == z43]
f5_z44 = f5.loc[f5['FUEL_TYPE'] == z44]
f5_z45 = f5.loc[f5['FUEL_TYPE'] == z45]
f5_z46 = f5.loc[f5['FUEL_TYPE'] == z46]
f5_z47 = f5.loc[f5['FUEL_TYPE'] == z47]
f5_z48 = f5.loc[f5['FUEL_TYPE'] == z48]
f5_z49 = f5.loc[f5['FUEL_TYPE'] == z49]
f5_z50 = f5.loc[f5['FUEL_TYPE'] == z50]
f5_z51 = f5.loc[f5['FUEL_TYPE'] == z51]
f5_z52 = f5.loc[f5['FUEL_TYPE'] == z52]
f5_z53 = f5.loc[f5['FUEL_TYPE'] == z53]
f5_z54 = f5.loc[f5['FUEL_TYPE'] == z54]
f5_z55 = f5.loc[f5['FUEL_TYPE'] == z55]
f5_z56 = f5.loc[f5['FUEL_TYPE'] == z56]
f5_z57 = f5.loc[f5['FUEL_TYPE'] == z57]
f5_z58 = f5.loc[f5['FUEL_TYPE'] == z58]
f5_z59 = f5.loc[f5['FUEL_TYPE'] == z59]
f5_z60 = f5.loc[f5['FUEL_TYPE'] == z60]
f5_z61 = f5.loc[f5['FUEL_TYPE'] == z61]
f5_z62 = f5.loc[f5['FUEL_TYPE'] == z62]
f5_z63 = f5.loc[f5['FUEL_TYPE'] == z63]

# rearrange the unit: select the entries which input heat capacit and aggregated high heat capacity are with unit of mmBtu/hr
f5_z1_mmBtu = f5_z1.loc[(f5_z1['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z1['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z2_mmBtu = f5_z2.loc[(f5_z2['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z2['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z3_mmBtu = f5_z3.loc[(f5_z3['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z3['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z4_mmBtu = f5_z4.loc[(f5_z4['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z4['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z5_mmBtu = f5_z5.loc[(f5_z5['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z5['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z6_mmBtu = f5_z6.loc[(f5_z6['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z6['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z7_mmBtu = f5_z7.loc[(f5_z7['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z7['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z8_mmBtu = f5_z8.loc[(f5_z8['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z8['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z9_mmBtu = f5_z9.loc[(f5_z9['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z9['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z10_mmBtu = f5_z10.loc[(f5_z10['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z10['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z11_mmBtu = f5_z11.loc[(f5_z11['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z11['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z12_mmBtu = f5_z12.loc[(f5_z12['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z12['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z13_mmBtu = f5_z13.loc[(f5_z13['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z13['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z14_mmBtu = f5_z14.loc[(f5_z14['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z14['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z15_mmBtu = f5_z15.loc[(f5_z15['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z15['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z16_mmBtu = f5_z16.loc[(f5_z16['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z16['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z17_mmBtu = f5_z17.loc[(f5_z17['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z17['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z18_mmBtu = f5_z18.loc[(f5_z18['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z18['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z19_mmBtu = f5_z19.loc[(f5_z19['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z19['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z20_mmBtu = f5_z20.loc[(f5_z20['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z20['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z21_mmBtu = f5_z21.loc[(f5_z21['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z21['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z22_mmBtu = f5_z22.loc[(f5_z22['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z22['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z23_mmBtu = f5_z23.loc[(f5_z23['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z23['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z24_mmBtu = f5_z24.loc[(f5_z24['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z24['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z25_mmBtu = f5_z25.loc[(f5_z25['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z25['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z26_mmBtu = f5_z26.loc[(f5_z26['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z26['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z27_mmBtu = f5_z27.loc[(f5_z27['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z27['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z28_mmBtu = f5_z28.loc[(f5_z28['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z28['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z29_mmBtu = f5_z29.loc[(f5_z29['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z29['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z30_mmBtu = f5_z30.loc[(f5_z30['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z30['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z31_mmBtu = f5_z31.loc[(f5_z31['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z31['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z32_mmBtu = f5_z32.loc[(f5_z32['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z32['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z33_mmBtu = f5_z33.loc[(f5_z33['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z33['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z34_mmBtu = f5_z34.loc[(f5_z34['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z34['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z35_mmBtu = f5_z35.loc[(f5_z35['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z35['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z36_mmBtu = f5_z36.loc[(f5_z36['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z36['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z37_mmBtu = f5_z37.loc[(f5_z37['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z37['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z38_mmBtu = f5_z38.loc[(f5_z38['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z38['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z39_mmBtu = f5_z39.loc[(f5_z39['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z39['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z40_mmBtu = f5_z40.loc[(f5_z40['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z40['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z41_mmBtu = f5_z41.loc[(f5_z41['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z41['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z42_mmBtu = f5_z42.loc[(f5_z42['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z42['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z43_mmBtu = f5_z43.loc[(f5_z43['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z43['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z44_mmBtu = f5_z44.loc[(f5_z44['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z44['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z45_mmBtu = f5_z45.loc[(f5_z45['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z45['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z46_mmBtu = f5_z46.loc[(f5_z46['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z46['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z47_mmBtu = f5_z47.loc[(f5_z47['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z47['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z48_mmBtu = f5_z48.loc[(f5_z48['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z48['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z49_mmBtu = f5_z49.loc[(f5_z49['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z49['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z50_mmBtu = f5_z50.loc[(f5_z50['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z50['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z51_mmBtu = f5_z51.loc[(f5_z51['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z51['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z52_mmBtu = f5_z52.loc[(f5_z52['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z52['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z53_mmBtu = f5_z53.loc[(f5_z53['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z53['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z54_mmBtu = f5_z54.loc[(f5_z54['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z54['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z55_mmBtu = f5_z55.loc[(f5_z55['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z55['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z56_mmBtu = f5_z56.loc[(f5_z56['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z56['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z57_mmBtu = f5_z57.loc[(f5_z57['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z57['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z58_mmBtu = f5_z58.loc[(f5_z58['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z58['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z59_mmBtu = f5_z59.loc[(f5_z59['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z59['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z60_mmBtu = f5_z60.loc[(f5_z60['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z60['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z61_mmBtu = f5_z61.loc[(f5_z61['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z61['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z62_mmBtu = f5_z62.loc[(f5_z62['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z62['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]
f5_z63_mmBtu = f5_z63.loc[(f5_z63['INPUT_HEAT_CAPACITY_UNIT'] == 'mmBtu/hr')|(f5_z63['AGGR_HIGH_HEAT_CAPACITY_UOM'] == 'mmBtu/hr')]

# %%
# convert other unit to mmBtu/hr
f5_z1_other = f5_z1.loc[(f5_z1['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z1_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z1_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z1.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z2_other = f5_z2.loc[(f5_z2['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z2_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z2_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z2.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z3_other = f5_z3.loc[(f5_z3['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z3_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z3_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z3.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z7_other = f5_z7.loc[(f5_z7['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z7_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z7_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z7.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z8_other = f5_z8.loc[(f5_z8['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z8_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z8_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z8.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z27_other = f5_z27.loc[(f5_z27['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z27_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z27_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z27.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z37_other = f5_z37.loc[(f5_z37['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z37_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z37_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z37.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z9_other = f5_z9.loc[(f5_z9['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z9_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z9_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z9.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z44_other = f5_z44.loc[(f5_z44['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z44_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z44_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z44.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z4_other = f5_z4.loc[(f5_z4['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z4_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z4_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z4.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z6_other = f5_z6.loc[(f5_z6['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z6_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z6_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z6.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z58_other = f5_z58.loc[(f5_z58['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z58_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z58_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z58.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu

f5_z59_other = f5_z59.loc[(f5_z59['INPUT_HEAT_CAPACITY_UNIT'] == 'Other')]
f5_z59_other.loc[:,('INPUT_HEAT_CAPACITY')] = f5_z59_other.apply(lambda x: x[('INPUT_HEAT_CAPACITY')]*Unit_other_z59.get(x['INPUT_HEAT_CAPACITY_UNIT_OTHER'],0), axis = 1) #Unit are mmBtu
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# combine entries with mmBtu unit and other units
f5_z1_tier1 = pd.concat([f5_z1_mmBtu,f5_z1_other]).reset_index()
f5_z2_tier1 = pd.concat([f5_z2_mmBtu,f5_z2_other]).reset_index()
f5_z3_tier1 = pd.concat([f5_z3_mmBtu,f5_z3_other]).reset_index()
f5_z7_tier1 = pd.concat([f5_z7_mmBtu,f5_z7_other]).reset_index()
f5_z8_tier1 = pd.concat([f5_z8_mmBtu,f5_z8_other]).reset_index()
f5_z27_tier1 = pd.concat([f5_z27_mmBtu,f5_z27_other]).reset_index()
f5_z37_tier1 = pd.concat([f5_z37_mmBtu,f5_z37_other]).reset_index()
f5_z9_tier1 = pd.concat([f5_z9_mmBtu,f5_z9_other]).reset_index()
f5_z44_tier1 = pd.concat([f5_z44_mmBtu,f5_z44_other]).reset_index()
f5_z4_tier1 = pd.concat([f5_z4_mmBtu,f5_z4_other]).reset_index()
f5_z6_tier1 = pd.concat([f5_z6_mmBtu,f5_z6_other]).reset_index()
f5_z58_tier1 = pd.concat([f5_z58_mmBtu,f5_z58_other]).reset_index()
f5_z59_tier1 = pd.concat([f5_z59_mmBtu,f5_z59_other]).reset_index()

# %%
# In order to drop the entries which energy consumption is greater than heat capacity, we need to make sure capacities are in float type
f5_z1_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z1_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z1_tier1['INPUT_HEAT_CAPACITY'] = f5_z1_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z2_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z2_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z2_tier1['INPUT_HEAT_CAPACITY'] = f5_z2_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z3_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z3_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z3_tier1['INPUT_HEAT_CAPACITY'] = f5_z3_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z4_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z4_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z4_tier1['INPUT_HEAT_CAPACITY'] = f5_z4_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z5['AGGR_HIGH_HEAT_CAPACITY'] = f5_z5['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z5['INPUT_HEAT_CAPACITY'] = f5_z5['INPUT_HEAT_CAPACITY'].astype(float)

f5_z6_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z6_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z6_tier1['INPUT_HEAT_CAPACITY'] = f5_z6_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z7_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z7_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z7_tier1['INPUT_HEAT_CAPACITY'] = f5_z7_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z8_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z8_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z8_tier1['INPUT_HEAT_CAPACITY'] = f5_z8_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z9_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z9_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z9_tier1['INPUT_HEAT_CAPACITY'] = f5_z9_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z10['AGGR_HIGH_HEAT_CAPACITY'] = f5_z10['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z10['INPUT_HEAT_CAPACITY'] = f5_z10['INPUT_HEAT_CAPACITY'].astype(float)

f5_z11['AGGR_HIGH_HEAT_CAPACITY'] = f5_z11['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z11['INPUT_HEAT_CAPACITY'] = f5_z11['INPUT_HEAT_CAPACITY'].astype(float)

f5_z12['AGGR_HIGH_HEAT_CAPACITY'] = f5_z12['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z12['INPUT_HEAT_CAPACITY'] = f5_z12['INPUT_HEAT_CAPACITY'].astype(float)

f5_z13['AGGR_HIGH_HEAT_CAPACITY'] = f5_z13['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z13['INPUT_HEAT_CAPACITY'] = f5_z13['INPUT_HEAT_CAPACITY'].astype(float)

f5_z14['AGGR_HIGH_HEAT_CAPACITY'] = f5_z14['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z14['INPUT_HEAT_CAPACITY'] = f5_z14['INPUT_HEAT_CAPACITY'].astype(float)

f5_z15['AGGR_HIGH_HEAT_CAPACITY'] = f5_z15['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z15['INPUT_HEAT_CAPACITY'] = f5_z15['INPUT_HEAT_CAPACITY'].astype(float)

f5_z16['AGGR_HIGH_HEAT_CAPACITY'] = f5_z16['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z16['INPUT_HEAT_CAPACITY'] = f5_z16['INPUT_HEAT_CAPACITY'].astype(float)

f5_z17['AGGR_HIGH_HEAT_CAPACITY'] = f5_z17['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z17['INPUT_HEAT_CAPACITY'] = f5_z17['INPUT_HEAT_CAPACITY'].astype(float)

f5_z18['AGGR_HIGH_HEAT_CAPACITY'] = f5_z18['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z18['INPUT_HEAT_CAPACITY'] = f5_z18['INPUT_HEAT_CAPACITY'].astype(float)

f5_z19['AGGR_HIGH_HEAT_CAPACITY'] = f5_z19['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z19['INPUT_HEAT_CAPACITY'] = f5_z19['INPUT_HEAT_CAPACITY'].astype(float)

f5_z20['AGGR_HIGH_HEAT_CAPACITY'] = f5_z20['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z20['INPUT_HEAT_CAPACITY'] = f5_z20['INPUT_HEAT_CAPACITY'].astype(float)

f5_z21['AGGR_HIGH_HEAT_CAPACITY'] = f5_z21['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z21['INPUT_HEAT_CAPACITY'] = f5_z21['INPUT_HEAT_CAPACITY'].astype(float)

f5_z22['AGGR_HIGH_HEAT_CAPACITY'] = f5_z22['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z22['INPUT_HEAT_CAPACITY'] = f5_z22['INPUT_HEAT_CAPACITY'].astype(float)

f5_z23['AGGR_HIGH_HEAT_CAPACITY'] = f5_z23['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z23['INPUT_HEAT_CAPACITY'] = f5_z23['INPUT_HEAT_CAPACITY'].astype(float)

f5_z24['AGGR_HIGH_HEAT_CAPACITY'] = f5_z24['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z24['INPUT_HEAT_CAPACITY'] = f5_z24['INPUT_HEAT_CAPACITY'].astype(float)

f5_z25['AGGR_HIGH_HEAT_CAPACITY'] = f5_z25['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z25['INPUT_HEAT_CAPACITY'] = f5_z25['INPUT_HEAT_CAPACITY'].astype(float)

f5_z26['AGGR_HIGH_HEAT_CAPACITY'] = f5_z26['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z26['INPUT_HEAT_CAPACITY'] = f5_z26['INPUT_HEAT_CAPACITY'].astype(float)

f5_z27_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z27_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z27_tier1['INPUT_HEAT_CAPACITY'] = f5_z27_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z28['AGGR_HIGH_HEAT_CAPACITY'] = f5_z28['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z28['INPUT_HEAT_CAPACITY'] = f5_z28['INPUT_HEAT_CAPACITY'].astype(float)

f5_z29['AGGR_HIGH_HEAT_CAPACITY'] = f5_z29['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z29['INPUT_HEAT_CAPACITY'] = f5_z29['INPUT_HEAT_CAPACITY'].astype(float)

f5_z30['AGGR_HIGH_HEAT_CAPACITY'] = f5_z30['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z30['INPUT_HEAT_CAPACITY'] = f5_z30['INPUT_HEAT_CAPACITY'].astype(float)

f5_z31['AGGR_HIGH_HEAT_CAPACITY'] = f5_z31['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z31['INPUT_HEAT_CAPACITY'] = f5_z31['INPUT_HEAT_CAPACITY'].astype(float)

f5_z32['AGGR_HIGH_HEAT_CAPACITY'] = f5_z32['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z32['INPUT_HEAT_CAPACITY'] = f5_z32['INPUT_HEAT_CAPACITY'].astype(float)

f5_z33['AGGR_HIGH_HEAT_CAPACITY'] = f5_z33['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z33['INPUT_HEAT_CAPACITY'] = f5_z33['INPUT_HEAT_CAPACITY'].astype(float)

f5_z34['AGGR_HIGH_HEAT_CAPACITY'] = f5_z34['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z34['INPUT_HEAT_CAPACITY'] = f5_z34['INPUT_HEAT_CAPACITY'].astype(float)

f5_z35['AGGR_HIGH_HEAT_CAPACITY'] = f5_z35['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z35['INPUT_HEAT_CAPACITY'] = f5_z35['INPUT_HEAT_CAPACITY'].astype(float)

f5_z36['AGGR_HIGH_HEAT_CAPACITY'] = f5_z36['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z36['INPUT_HEAT_CAPACITY'] = f5_z36['INPUT_HEAT_CAPACITY'].astype(float)

f5_z37_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z37_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z37_tier1['INPUT_HEAT_CAPACITY'] = f5_z37_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z38['AGGR_HIGH_HEAT_CAPACITY'] = f5_z38['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z38['INPUT_HEAT_CAPACITY'] = f5_z38['INPUT_HEAT_CAPACITY'].astype(float)

f5_z39['AGGR_HIGH_HEAT_CAPACITY'] = f5_z39['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z39['INPUT_HEAT_CAPACITY'] = f5_z39['INPUT_HEAT_CAPACITY'].astype(float)

f5_z40['AGGR_HIGH_HEAT_CAPACITY'] = f5_z40['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z40['INPUT_HEAT_CAPACITY'] = f5_z40['INPUT_HEAT_CAPACITY'].astype(float)

f5_z41['AGGR_HIGH_HEAT_CAPACITY'] = f5_z41['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z41['INPUT_HEAT_CAPACITY'] = f5_z41['INPUT_HEAT_CAPACITY'].astype(float)

f5_z42['AGGR_HIGH_HEAT_CAPACITY'] = f5_z42['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z42['INPUT_HEAT_CAPACITY'] = f5_42['INPUT_HEAT_CAPACITY'].astype(float)

f5_z43['AGGR_HIGH_HEAT_CAPACITY'] = f5_z43['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z43['INPUT_HEAT_CAPACITY'] = f5_z43['INPUT_HEAT_CAPACITY'].astype(float)

f5_z44_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z44_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z44_tier1['INPUT_HEAT_CAPACITY'] = f5_z44_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z45['AGGR_HIGH_HEAT_CAPACITY'] = f5_z45['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z45['INPUT_HEAT_CAPACITY'] = f5_z45['INPUT_HEAT_CAPACITY'].astype(float)

f5_z46['AGGR_HIGH_HEAT_CAPACITY'] = f5_z46['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z46['INPUT_HEAT_CAPACITY'] = f5_z46['INPUT_HEAT_CAPACITY'].astype(float)

f5_z47['AGGR_HIGH_HEAT_CAPACITY'] = f5_z47['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z47['INPUT_HEAT_CAPACITY'] = f5_z47['INPUT_HEAT_CAPACITY'].astype(float)

f5_z48['AGGR_HIGH_HEAT_CAPACITY'] = f5_z48['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z48['INPUT_HEAT_CAPACITY'] = f5_z48['INPUT_HEAT_CAPACITY'].astype(float)

f5_z49['AGGR_HIGH_HEAT_CAPACITY'] = f5_z49['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z49['INPUT_HEAT_CAPACITY'] = f5_z49['INPUT_HEAT_CAPACITY'].astype(float)

f5_z50['AGGR_HIGH_HEAT_CAPACITY'] = f5_z50['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z50['INPUT_HEAT_CAPACITY'] = f5_z50['INPUT_HEAT_CAPACITY'].astype(float)

f5_z51['AGGR_HIGH_HEAT_CAPACITY'] = f5_z51['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z51['INPUT_HEAT_CAPACITY'] = f5_z51['INPUT_HEAT_CAPACITY'].astype(float)

f5_z52['AGGR_HIGH_HEAT_CAPACITY'] = f5_z52['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z52['INPUT_HEAT_CAPACITY'] = f5_z52['INPUT_HEAT_CAPACITY'].astype(float)

f5_z53['AGGR_HIGH_HEAT_CAPACITY'] = f5_z53['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z53['INPUT_HEAT_CAPACITY'] = f5_z53['INPUT_HEAT_CAPACITY'].astype(float)

f5_z54['AGGR_HIGH_HEAT_CAPACITY'] = f5_z54['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z54['INPUT_HEAT_CAPACITY'] = f5_z54['INPUT_HEAT_CAPACITY'].astype(float)

f5_z55['AGGR_HIGH_HEAT_CAPACITY'] = f5_z55['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z55['INPUT_HEAT_CAPACITY'] = f5_z55['INPUT_HEAT_CAPACITY'].astype(float)

f5_z56['AGGR_HIGH_HEAT_CAPACITY'] = f5_z56['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z56['INPUT_HEAT_CAPACITY'] = f5_z56['INPUT_HEAT_CAPACITY'].astype(float)

f5_z57['AGGR_HIGH_HEAT_CAPACITY'] = f5_z57['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z57['INPUT_HEAT_CAPACITY'] = f5_z57['INPUT_HEAT_CAPACITY'].astype(float)

f5_z58_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z58_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z58_tier1['INPUT_HEAT_CAPACITY'] = f5_z58_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z59_tier1['AGGR_HIGH_HEAT_CAPACITY'] = f5_z59_tier1['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z59_tier1['INPUT_HEAT_CAPACITY'] = f5_z59_tier1['INPUT_HEAT_CAPACITY'].astype(float)

f5_z60['AGGR_HIGH_HEAT_CAPACITY'] = f5_z60['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z60['INPUT_HEAT_CAPACITY'] = f5_z60['INPUT_HEAT_CAPACITY'].astype(float)

f5_z61['AGGR_HIGH_HEAT_CAPACITY'] = f5_z61['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z61['INPUT_HEAT_CAPACITY'] = f5_z61['INPUT_HEAT_CAPACITY'].astype(float)

f5_z62['AGGR_HIGH_HEAT_CAPACITY'] = f5_z62['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z62['INPUT_HEAT_CAPACITY'] = f5_z62['INPUT_HEAT_CAPACITY'].astype(float)

f5_z63['AGGR_HIGH_HEAT_CAPACITY'] = f5_z63['AGGR_HIGH_HEAT_CAPACITY'].astype(float)
f5_z63['INPUT_HEAT_CAPACITY'] = f5_z63['INPUT_HEAT_CAPACITY'].astype(float)
# Out:
# C:\Users\zhang\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\zhang\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\zhang\anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# in order to find valid entries, we compare energy consumption (mmbtu/hr) with heat capacity (mmbtu/hr)
f5_z1_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z1_tier1.loc[:,'ENERGY_COM']/365/24
f5_z2_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z2_tier1.loc[:,'ENERGY_COM']/365/24
f5_z3_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z3_tier1.loc[:,'ENERGY_COM']/365/24
f5_z4_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z4_tier1.loc[:,'ENERGY_COM']/365/24
f5_z5.loc[:,'ENERGY_MMBtu_hr'] = f5_z5.loc[:,'ENERGY_COM']/365/24
f5_z6_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z6_tier1.loc[:,'ENERGY_COM']/365/24
f5_z7_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z7_tier1.loc[:,'ENERGY_COM']/365/24
f5_z8_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z8_tier1.loc[:,'ENERGY_COM']/365/24
f5_z9_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z9_tier1.loc[:,'ENERGY_COM']/365/24
f5_z10.loc[:,'ENERGY_MMBtu_hr'] = f5_z10.loc[:,'ENERGY_COM']/365/24
f5_z11.loc[:,'ENERGY_MMBtu_hr'] = f5_z11.loc[:,'ENERGY_COM']/365/24
f5_z12.loc[:,'ENERGY_MMBtu_hr'] = f5_z12.loc[:,'ENERGY_COM']/365/24
f5_z13.loc[:,'ENERGY_MMBtu_hr'] = f5_z13.loc[:,'ENERGY_COM']/365/24
f5_z14.loc[:,'ENERGY_MMBtu_hr'] = f5_z14.loc[:,'ENERGY_COM']/365/24
f5_z15.loc[:,'ENERGY_MMBtu_hr'] = f5_z15.loc[:,'ENERGY_COM']/365/24
f5_z16.loc[:,'ENERGY_MMBtu_hr'] = f5_z16.loc[:,'ENERGY_COM']/365/24
f5_z17.loc[:,'ENERGY_MMBtu_hr'] = f5_z17.loc[:,'ENERGY_COM']/365/24
f5_z18.loc[:,'ENERGY_MMBtu_hr'] = f5_z18.loc[:,'ENERGY_COM']/365/24
f5_z19.loc[:,'ENERGY_MMBtu_hr'] = f5_z19.loc[:,'ENERGY_COM']/365/24
f5_z20.loc[:,'ENERGY_MMBtu_hr'] = f5_z20.loc[:,'ENERGY_COM']/365/24
f5_z21.loc[:,'ENERGY_MMBtu_hr'] = f5_z21.loc[:,'ENERGY_COM']/365/24
f5_z22.loc[:,'ENERGY_MMBtu_hr'] = f5_z22.loc[:,'ENERGY_COM']/365/24
f5_z23.loc[:,'ENERGY_MMBtu_hr'] = f5_z23.loc[:,'ENERGY_COM']/365/24
f5_z24.loc[:,'ENERGY_MMBtu_hr'] = f5_z24.loc[:,'ENERGY_COM']/365/24
f5_z25.loc[:,'ENERGY_MMBtu_hr'] = f5_z25.loc[:,'ENERGY_COM']/365/24
f5_z26.loc[:,'ENERGY_MMBtu_hr'] = f5_z26.loc[:,'ENERGY_COM']/365/24
f5_z27_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z27_tier1.loc[:,'ENERGY_COM']/365/24
f5_z28.loc[:,'ENERGY_MMBtu_hr'] = f5_z28.loc[:,'ENERGY_COM']/365/24
f5_z29.loc[:,'ENERGY_MMBtu_hr'] = f5_z29.loc[:,'ENERGY_COM']/365/24
f5_z30.loc[:,'ENERGY_MMBtu_hr'] = f5_z30.loc[:,'ENERGY_COM']/365/24
f5_z31.loc[:,'ENERGY_MMBtu_hr'] = f5_z31.loc[:,'ENERGY_COM']/365/24
f5_z32.loc[:,'ENERGY_MMBtu_hr'] = f5_z32.loc[:,'ENERGY_COM']/365/24
f5_z33.loc[:,'ENERGY_MMBtu_hr'] = f5_z33.loc[:,'ENERGY_COM']/365/24
f5_z34.loc[:,'ENERGY_MMBtu_hr'] = f5_z34.loc[:,'ENERGY_COM']/365/24
f5_z35.loc[:,'ENERGY_MMBtu_hr'] = f5_z35.loc[:,'ENERGY_COM']/365/24
f5_z36.loc[:,'ENERGY_MMBtu_hr'] = f5_z36.loc[:,'ENERGY_COM']/365/24
f5_z37_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z37_tier1.loc[:,'ENERGY_COM']/365/24
f5_z38.loc[:,'ENERGY_MMBtu_hr'] = f5_z38.loc[:,'ENERGY_COM']/365/24
f5_z39.loc[:,'ENERGY_MMBtu_hr'] = f5_z39.loc[:,'ENERGY_COM']/365/24
f5_z40.loc[:,'ENERGY_MMBtu_hr'] = f5_z40.loc[:,'ENERGY_COM']/365/24
f5_z41.loc[:,'ENERGY_MMBtu_hr'] = f5_z41.loc[:,'ENERGY_COM']/365/24
f5_z42.loc[:,'ENERGY_MMBtu_hr'] = f5_z42.loc[:,'ENERGY_COM']/365/24
f5_z43.loc[:,'ENERGY_MMBtu_hr'] = f5_z43.loc[:,'ENERGY_COM']/365/24
f5_z44_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z44_tier1.loc[:,'ENERGY_COM']/365/24
f5_z45.loc[:,'ENERGY_MMBtu_hr'] = f5_z45.loc[:,'ENERGY_COM']/365/24
f5_z46.loc[:,'ENERGY_MMBtu_hr'] = f5_z46.loc[:,'ENERGY_COM']/365/24
f5_z47.loc[:,'ENERGY_MMBtu_hr'] = f5_z47.loc[:,'ENERGY_COM']/365/24
f5_z48.loc[:,'ENERGY_MMBtu_hr'] = f5_z48.loc[:,'ENERGY_COM']/365/24
f5_z49.loc[:,'ENERGY_MMBtu_hr'] = f5_z49.loc[:,'ENERGY_COM']/365/24
f5_z50.loc[:,'ENERGY_MMBtu_hr'] = f5_z50.loc[:,'ENERGY_COM']/365/24
f5_z51.loc[:,'ENERGY_MMBtu_hr'] = f5_z51.loc[:,'ENERGY_COM']/365/24
f5_z52.loc[:,'ENERGY_MMBtu_hr'] = f5_z52.loc[:,'ENERGY_COM']/365/24
f5_z53.loc[:,'ENERGY_MMBtu_hr'] = f5_z53.loc[:,'ENERGY_COM']/365/24
f5_z54.loc[:,'ENERGY_MMBtu_hr'] = f5_z54.loc[:,'ENERGY_COM']/365/24
f5_z55.loc[:,'ENERGY_MMBtu_hr'] = f5_z55.loc[:,'ENERGY_COM']/365/24
f5_z56.loc[:,'ENERGY_MMBtu_hr'] = f5_z56.loc[:,'ENERGY_COM']/365/24
f5_z57.loc[:,'ENERGY_MMBtu_hr'] = f5_z57.loc[:,'ENERGY_COM']/365/24
f5_z58_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z58_tier1.loc[:,'ENERGY_COM']/365/24
f5_z59_tier1.loc[:,'ENERGY_MMBtu_hr'] = f5_z59_tier1.loc[:,'ENERGY_COM']/365/24
f5_z60.loc[:,'ENERGY_MMBtu_hr'] = f5_z60.loc[:,'ENERGY_COM']/365/24
f5_z61.loc[:,'ENERGY_MMBtu_hr'] = f5_z61.loc[:,'ENERGY_COM']/365/24
f5_z62.loc[:,'ENERGY_MMBtu_hr'] = f5_z62.loc[:,'ENERGY_COM']/365/24
f5_z63.loc[:,'ENERGY_MMBtu_hr'] = f5_z63.loc[:,'ENERGY_COM']/365/24

# %%
#select the entries which the capacity is greater or equal to energy consumption (drop the entries which energy consumption > capacity)
f5_z1_tier1 = f5_z1_tier1[(f5_z1_tier1['ENERGY_MMBtu_hr']<=f5_z1_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z1_tier1['ENERGY_MMBtu_hr']<=f5_z1_tier1['INPUT_HEAT_CAPACITY'])]
f5_z2_tier1 = f5_z2_tier1[(f5_z2_tier1['ENERGY_MMBtu_hr']<=f5_z2_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z2_tier1['ENERGY_MMBtu_hr']<=f5_z2_tier1['INPUT_HEAT_CAPACITY'])]
f5_z3_tier1 = f5_z3_tier1[(f5_z3_tier1['ENERGY_MMBtu_hr']<=f5_z3_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z3_tier1['ENERGY_MMBtu_hr']<=f5_z3_tier1['INPUT_HEAT_CAPACITY'])]
f5_z4_tier1 = f5_z4_tier1[(f5_z4_tier1['ENERGY_MMBtu_hr']<=f5_z4_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z4_tier1['ENERGY_MMBtu_hr']<=f5_z4_tier1['INPUT_HEAT_CAPACITY'])]
f5_z5 = f5_z5[(f5_z5['ENERGY_MMBtu_hr']<=f5_z5['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z5['ENERGY_MMBtu_hr']<=f5_z5['INPUT_HEAT_CAPACITY'])]
f5_z6_tier1 = f5_z6_tier1[(f5_z6_tier1['ENERGY_MMBtu_hr']<=f5_z6_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z6_tier1['ENERGY_MMBtu_hr']<=f5_z6_tier1['INPUT_HEAT_CAPACITY'])]
f5_z7_tier1 = f5_z7_tier1[(f5_z7_tier1['ENERGY_MMBtu_hr']<=f5_z7_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z7_tier1['ENERGY_MMBtu_hr']<=f5_z7_tier1['INPUT_HEAT_CAPACITY'])]
f5_z8_tier1 = f5_z8_tier1[(f5_z8_tier1['ENERGY_MMBtu_hr']<=f5_z8_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z8_tier1['ENERGY_MMBtu_hr']<=f5_z8_tier1['INPUT_HEAT_CAPACITY'])]
f5_z9_tier1 = f5_z9_tier1[(f5_z9_tier1['ENERGY_MMBtu_hr']<=f5_z9_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z9_tier1['ENERGY_MMBtu_hr']<=f5_z9_tier1['INPUT_HEAT_CAPACITY'])]
f5_z10 = f5_z10[(f5_z10['ENERGY_MMBtu_hr']<=f5_z10['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z10['ENERGY_MMBtu_hr']<=f5_z10['INPUT_HEAT_CAPACITY'])]
f5_z11 = f5_z11[(f5_z11['ENERGY_MMBtu_hr']<=f5_z11['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z11['ENERGY_MMBtu_hr']<=f5_z11['INPUT_HEAT_CAPACITY'])]
f5_z12 = f5_z12[(f5_z12['ENERGY_MMBtu_hr']<=f5_z12['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z12['ENERGY_MMBtu_hr']<=f5_z12['INPUT_HEAT_CAPACITY'])]
f5_z13 = f5_z13[(f5_z13['ENERGY_MMBtu_hr']<=f5_z13['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z13['ENERGY_MMBtu_hr']<=f5_z13['INPUT_HEAT_CAPACITY'])]
f5_z14 = f5_z14[(f5_z14['ENERGY_MMBtu_hr']<=f5_z14['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z14['ENERGY_MMBtu_hr']<=f5_z14['INPUT_HEAT_CAPACITY'])]
f5_z15 = f5_z15[(f5_z15['ENERGY_MMBtu_hr']<=f5_z15['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z15['ENERGY_MMBtu_hr']<=f5_z15['INPUT_HEAT_CAPACITY'])]
f5_z16 = f5_z16[(f5_z16['ENERGY_MMBtu_hr']<=f5_z16['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z16['ENERGY_MMBtu_hr']<=f5_z16['INPUT_HEAT_CAPACITY'])]
f5_z17 = f5_z17[(f5_z17['ENERGY_MMBtu_hr']<=f5_z17['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z17['ENERGY_MMBtu_hr']<=f5_z17['INPUT_HEAT_CAPACITY'])]
f5_z18 = f5_z18[(f5_z18['ENERGY_MMBtu_hr']<=f5_z18['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z18['ENERGY_MMBtu_hr']<=f5_z18['INPUT_HEAT_CAPACITY'])]
f5_z19 = f5_z19[(f5_z19['ENERGY_MMBtu_hr']<=f5_z19['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z19['ENERGY_MMBtu_hr']<=f5_z19['INPUT_HEAT_CAPACITY'])]
f5_z20 = f5_z20[(f5_z20['ENERGY_MMBtu_hr']<=f5_z20['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z20['ENERGY_MMBtu_hr']<=f5_z20['INPUT_HEAT_CAPACITY'])]
f5_z21 = f5_z21[(f5_z21['ENERGY_MMBtu_hr']<=f5_z21['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z21['ENERGY_MMBtu_hr']<=f5_z21['INPUT_HEAT_CAPACITY'])]
f5_z22 = f5_z22[(f5_z22['ENERGY_MMBtu_hr']<=f5_z22['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z22['ENERGY_MMBtu_hr']<=f5_z22['INPUT_HEAT_CAPACITY'])]
f5_z23 = f5_z23[(f5_z23['ENERGY_MMBtu_hr']<=f5_z23['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z23['ENERGY_MMBtu_hr']<=f5_z23['INPUT_HEAT_CAPACITY'])]
f5_z24 = f5_z24[(f5_z24['ENERGY_MMBtu_hr']<=f5_z24['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z24['ENERGY_MMBtu_hr']<=f5_z24['INPUT_HEAT_CAPACITY'])]
f5_z25 = f5_z25[(f5_z25['ENERGY_MMBtu_hr']<=f5_z25['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z25['ENERGY_MMBtu_hr']<=f5_z25['INPUT_HEAT_CAPACITY'])]
f5_z26 = f5_z26[(f5_z26['ENERGY_MMBtu_hr']<=f5_z26['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z26['ENERGY_MMBtu_hr']<=f5_z26['INPUT_HEAT_CAPACITY'])]
f5_z27_tier1 = f5_z27_tier1[(f5_z27_tier1['ENERGY_MMBtu_hr']<=f5_z27_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z27_tier1['ENERGY_MMBtu_hr']<=f5_z27_tier1['INPUT_HEAT_CAPACITY'])]
f5_z28 = f5_z28[(f5_z28['ENERGY_MMBtu_hr']<=f5_z28['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z28['ENERGY_MMBtu_hr']<=f5_z28['INPUT_HEAT_CAPACITY'])]
f5_z29 = f5_z29[(f5_z29['ENERGY_MMBtu_hr']<=f5_z29['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z29['ENERGY_MMBtu_hr']<=f5_z29['INPUT_HEAT_CAPACITY'])]
f5_z30 = f5_z30[(f5_z30['ENERGY_MMBtu_hr']<=f5_z30['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z30['ENERGY_MMBtu_hr']<=f5_z30['INPUT_HEAT_CAPACITY'])]
f5_z31 = f5_z31[(f5_z31['ENERGY_MMBtu_hr']<=f5_z31['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z31['ENERGY_MMBtu_hr']<=f5_z31['INPUT_HEAT_CAPACITY'])]
f5_z32 = f5_z32[(f5_z32['ENERGY_MMBtu_hr']<=f5_z32['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z32['ENERGY_MMBtu_hr']<=f5_z32['INPUT_HEAT_CAPACITY'])]
f5_z33 = f5_z33[(f5_z33['ENERGY_MMBtu_hr']<=f5_z33['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z33['ENERGY_MMBtu_hr']<=f5_z33['INPUT_HEAT_CAPACITY'])]
f5_z34 = f5_z34[(f5_z34['ENERGY_MMBtu_hr']<=f5_z34['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z34['ENERGY_MMBtu_hr']<=f5_z34['INPUT_HEAT_CAPACITY'])]
f5_z35 = f5_z35[(f5_z35['ENERGY_MMBtu_hr']<=f5_z35['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z35['ENERGY_MMBtu_hr']<=f5_z35['INPUT_HEAT_CAPACITY'])]
f5_z36 = f5_z36[(f5_z36['ENERGY_MMBtu_hr']<=f5_z36['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z36['ENERGY_MMBtu_hr']<=f5_z36['INPUT_HEAT_CAPACITY'])]
f5_z37_tier1 = f5_z37_tier1[(f5_z37_tier1['ENERGY_MMBtu_hr']<=f5_z37_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z37_tier1['ENERGY_MMBtu_hr']<=f5_z37_tier1['INPUT_HEAT_CAPACITY'])]
f5_z38 = f5_z38[(f5_z38['ENERGY_MMBtu_hr']<=f5_z38['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z38['ENERGY_MMBtu_hr']<=f5_z38['INPUT_HEAT_CAPACITY'])]
f5_z39 = f5_z39[(f5_z39['ENERGY_MMBtu_hr']<=f5_z39['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z39['ENERGY_MMBtu_hr']<=f5_z39['INPUT_HEAT_CAPACITY'])]
f5_z40 = f5_z40[(f5_z40['ENERGY_MMBtu_hr']<=f5_z40['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z40['ENERGY_MMBtu_hr']<=f5_z40['INPUT_HEAT_CAPACITY'])]
f5_z41 = f5_z41[(f5_z41['ENERGY_MMBtu_hr']<=f5_z41['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z41['ENERGY_MMBtu_hr']<=f5_z41['INPUT_HEAT_CAPACITY'])]
f5_z42 = f5_z42[(f5_z42['ENERGY_MMBtu_hr']<=f5_z42['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z42['ENERGY_MMBtu_hr']<=f5_z42['INPUT_HEAT_CAPACITY'])]
f5_z43 = f5_z43[(f5_z43['ENERGY_MMBtu_hr']<=f5_z43['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z43['ENERGY_MMBtu_hr']<=f5_z43['INPUT_HEAT_CAPACITY'])]
f5_z44_tier1 = f5_z44_tier1[(f5_z44_tier1['ENERGY_MMBtu_hr']<=f5_z44_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z44_tier1['ENERGY_MMBtu_hr']<=f5_z44_tier1['INPUT_HEAT_CAPACITY'])]
f5_z45 = f5_z45[(f5_z45['ENERGY_MMBtu_hr']<=f5_z45['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z45['ENERGY_MMBtu_hr']<=f5_z45['INPUT_HEAT_CAPACITY'])]
f5_z46 = f5_z46[(f5_z46['ENERGY_MMBtu_hr']<=f5_z46['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z46['ENERGY_MMBtu_hr']<=f5_z46['INPUT_HEAT_CAPACITY'])]
f5_z47 = f5_z47[(f5_z47['ENERGY_MMBtu_hr']<=f5_z47['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z47['ENERGY_MMBtu_hr']<=f5_z47['INPUT_HEAT_CAPACITY'])]
f5_z48 = f5_z48[(f5_z48['ENERGY_MMBtu_hr']<=f5_z48['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z48['ENERGY_MMBtu_hr']<=f5_z48['INPUT_HEAT_CAPACITY'])]
f5_z49 = f5_z49[(f5_z49['ENERGY_MMBtu_hr']<=f5_z49['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z49['ENERGY_MMBtu_hr']<=f5_z49['INPUT_HEAT_CAPACITY'])]
f5_z50 = f5_z50[(f5_z50['ENERGY_MMBtu_hr']<=f5_z50['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z50['ENERGY_MMBtu_hr']<=f5_z50['INPUT_HEAT_CAPACITY'])]
f5_z51 = f5_z51[(f5_z51['ENERGY_MMBtu_hr']<=f5_z51['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z51['ENERGY_MMBtu_hr']<=f5_z51['INPUT_HEAT_CAPACITY'])]
f5_z52 = f5_z52[(f5_z52['ENERGY_MMBtu_hr']<=f5_z52['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z52['ENERGY_MMBtu_hr']<=f5_z52['INPUT_HEAT_CAPACITY'])]
f5_z53 = f5_z53[(f5_z53['ENERGY_MMBtu_hr']<=f5_z53['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z53['ENERGY_MMBtu_hr']<=f5_z53['INPUT_HEAT_CAPACITY'])]
f5_z54 = f5_z54[(f5_z54['ENERGY_MMBtu_hr']<=f5_z54['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z54['ENERGY_MMBtu_hr']<=f5_z54['INPUT_HEAT_CAPACITY'])]
f5_z55 = f5_z55[(f5_z55['ENERGY_MMBtu_hr']<=f5_z55['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z55['ENERGY_MMBtu_hr']<=f5_z55['INPUT_HEAT_CAPACITY'])]
f5_z56 = f5_z56[(f5_z56['ENERGY_MMBtu_hr']<=f5_z56['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z56['ENERGY_MMBtu_hr']<=f5_z56['INPUT_HEAT_CAPACITY'])]
f5_z57 = f5_z57[(f5_z57['ENERGY_MMBtu_hr']<=f5_z57['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z57['ENERGY_MMBtu_hr']<=f5_z57['INPUT_HEAT_CAPACITY'])]
f5_z58_tier1 = f5_z58_tier1[(f5_z58_tier1['ENERGY_MMBtu_hr']<=f5_z58_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z58_tier1['ENERGY_MMBtu_hr']<=f5_z58_tier1['INPUT_HEAT_CAPACITY'])]
f5_z59_tier1 = f5_z59_tier1[(f5_z59_tier1['ENERGY_MMBtu_hr']<=f5_z59_tier1['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z59_tier1['ENERGY_MMBtu_hr']<=f5_z59_tier1['INPUT_HEAT_CAPACITY'])]
f5_z60 = f5_z60[(f5_z60['ENERGY_MMBtu_hr']<=f5_z60['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z60['ENERGY_MMBtu_hr']<=f5_z60['INPUT_HEAT_CAPACITY'])]
f5_z61 = f5_z61[(f5_z61['ENERGY_MMBtu_hr']<=f5_z61['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z61['ENERGY_MMBtu_hr']<=f5_z61['INPUT_HEAT_CAPACITY'])]
f5_z62 = f5_z62[(f5_z62['ENERGY_MMBtu_hr']<=f5_z62['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z62['ENERGY_MMBtu_hr']<=f5_z62['INPUT_HEAT_CAPACITY'])]
f5_z63 = f5_z63[(f5_z63['ENERGY_MMBtu_hr']<=f5_z63['AGGR_HIGH_HEAT_CAPACITY'])|(f5_z63['ENERGY_MMBtu_hr']<=f5_z63['INPUT_HEAT_CAPACITY'])]

# %%
f5_overall = pd.concat([f5_z1_tier1,f5_z2_tier1,f5_z3_tier1,f5_z4_tier1,f5_z5,f5_z6_tier1,f5_z7_tier1,f5_z8_tier1,f5_z9_tier1,f5_z10,f5_z11,f5_z12,f5_z13,f5_z14,f5_z15,f5_z16,f5_z17,f5_z18,f5_z19,f5_z20,f5_z21,f5_z22,f5_z23,f5_z24,f5_z25,f5_z26,f5_z27_tier1,f5_z28,f5_z29,f5_z30,f5_z31,f5_z32,f5_z33,f5_z34,f5_z35,f5_z36,f5_z37_tier1,f5_z38,f5_z39,f5_z40,f5_z41,f5_z42,f5_z43,f5_z44_tier1,f5_z45,f5_z46,f5_z47,f5_z48,f5_z49,f5_z50,f5_z51,f5_z52,f5_z53,f5_z54,f5_z55,f5_z56,f5_z57,f5_z58_tier1,f5_z59_tier1,f5_z60,f5_z61,f5_z62,f5_z63])
f5_overall["INPUT_HEAT_CAPACITY_UNIT"]= f5_overall["INPUT_HEAT_CAPACITY_UNIT"].replace("Other", "mmBtu/hr") 
f5_overall.to_excel(r'C:\Users\zhang\Box\Boiler electrification potential\Tier1_final.xlsx', index = False)

# %%
#plot overall fuel usage and capacity
f5_overall = pd.concat([f5_z1_tier1,f5_z2_tier1,f5_z3_tier1,f5_z4_tier1,f5_z5,f5_z6_tier1,f5_z7_tier1,f5_z8_tier1,f5_z9_tier1,f5_z10,f5_z11,f5_z12,f5_z13,f5_z14,f5_z15,f5_z16,f5_z17,f5_z18,f5_z19,f5_z20,f5_z21,f5_z22,f5_z23,f5_z24,f5_z25,f5_z26,f5_z27_tier1,f5_z28,f5_z29,f5_z30,f5_z31,f5_z32,f5_z33,f5_z34,f5_z35,f5_z36,f5_z37_tier1,f5_z38,f5_z39,f5_z40,f5_z41,f5_z42,f5_z43,f5_z44_tier1,f5_z45,f5_z46,f5_z47,f5_z48,f5_z49,f5_z50,f5_z51,f5_z52,f5_z53,f5_z54,f5_z55,f5_z56,f5_z57,f5_z58_tier1,f5_z59_tier1,f5_z60,f5_z61,f5_z62,f5_z63])
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_overall['INPUT_HEAT_CAPACITY'][f5_overall['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_overall['ENERGY_COM'][f5_overall['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_overall['AGGR_HIGH_HEAT_CAPACITY'][f5_overall['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_overall['ENERGY_COM'][f5_overall['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper left')
plt.xlabel('heat capacity (mmBtu/yr)')
plt.ylabel('energy consumption (mmBtu/yr)')
plt.title('fuel usage vs capacity')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z1_tier1['INPUT_HEAT_CAPACITY'][f5_z1_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z1_tier1['FUEL_COM'][f5_z1_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z1_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z1_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z1_tier1['FUEL_COM'][f5_z1_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Distillate Fuel Oil No. 1')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z2_tier1['INPUT_HEAT_CAPACITY'][f5_z2_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z2_tier1['ENERGY_COM'][f5_z2_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z2_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z2_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z2_tier1['FUEL_COM'][f5_z2_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Distillate Fuel Oil No. 2')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z3_tier1['INPUT_HEAT_CAPACITY'][f5_z3_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z3_tier1['ENERGY_COM'][f5_z3_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z3_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z3_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z3_tier1['FUEL_COM'][f5_z3_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Distillate Fuel Oil No. 4')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z4_tier1['INPUT_HEAT_CAPACITY'][f5_z4_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z4_tier1['ENERGY_COM'][f5_z4_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z4_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z4_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z4_tier1['FUEL_COM'][f5_z4_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Residual Fuel Oil No. 5')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z5['INPUT_HEAT_CAPACITY'][f5_z5['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z5['ENERGY_COM'][f5_z5['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z5['AGGR_HIGH_HEAT_CAPACITY'][f5_z5['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z5['FUEL_COM'][f5_z5['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Residual Fuel Oil No. 6')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z6_tier1['INPUT_HEAT_CAPACITY'][f5_z6_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z6_tier1['ENERGY_COM'][f5_z6_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z6_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z6_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z6_tier1['FUEL_COM'][f5_z6_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Used Oil')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z7_tier1['INPUT_HEAT_CAPACITY'][f5_z7_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z7_tier1['ENERGY_COM'][f5_z7_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z7_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z7_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z7_tier1['FUEL_COM'][f5_z7_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Kerosene')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z8_tier1['INPUT_HEAT_CAPACITY'][f5_z8_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z8_tier1['ENERGY_COM'][f5_z8_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z8_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z8_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z8_tier1['FUEL_COM'][f5_z8_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Liquefied petroleum gases (LPG)')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z9_tier1['INPUT_HEAT_CAPACITY'][f5_z9_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z9_tier1['ENERGY_COM'][f5_z9_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z9_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z9_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z9_tier1['FUEL_COM'][f5_z9_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Propane')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z10['INPUT_HEAT_CAPACITY'][f5_z10['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z10['ENERGY_COM'][f5_z10['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z10['AGGR_HIGH_HEAT_CAPACITY'][f5_z10['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z10['FUEL_COM'][f5_z10['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Propylene')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z11['INPUT_HEAT_CAPACITY'][f5_z11['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z11['ENERGY_COM'][f5_z11['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z11['AGGR_HIGH_HEAT_CAPACITY'][f5_z11['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z11['FUEL_COM'][f5_z11['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Ethane')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z12['INPUT_HEAT_CAPACITY'][f5_z12['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z12['ENERGY_COM'][f5_z12['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z12['AGGR_HIGH_HEAT_CAPACITY'][f5_z12['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z12['FUEL_COM'][f5_z12['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

ax1.scatter(f5_z36['INPUT_HEAT_CAPACITY'][f5_z36['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z36['ENERGY_COM'][f5_z36['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z36['AGGR_HIGH_HEAT_CAPACITY'][f5_z36['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z36['FUEL_COM'][f5_z36['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Ethanol')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z13['INPUT_HEAT_CAPACITY'][f5_z13['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z13['ENERGY_COM'][f5_z13['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z13['AGGR_HIGH_HEAT_CAPACITY'][f5_z13['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z13['FUEL_COM'][f5_z13['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Ethylene')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z14['INPUT_HEAT_CAPACITY'][f5_z14['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z14['ENERGY_COM'][f5_z14['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z14['AGGR_HIGH_HEAT_CAPACITY'][f5_z14['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z14['FUEL_COM'][f5_z14['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Isobutane')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z15['INPUT_HEAT_CAPACITY'][f5_z15['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z15['ENERGY_COM'][f5_z15['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z15['AGGR_HIGH_HEAT_CAPACITY'][f5_z15['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z15['FUEL_COM'][f5_z15['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Isobutylene')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z16['INPUT_HEAT_CAPACITY'][f5_z16['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z16['ENERGY_COM'][f5_z16['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z16['AGGR_HIGH_HEAT_CAPACITY'][f5_z16['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z16['FUEL_COM'][f5_z16['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Butane')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z17['INPUT_HEAT_CAPACITY'][f5_z17['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z17['ENERGY_COM'][f5_z17['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z17['AGGR_HIGH_HEAT_CAPACITY'][f5_z17['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z17['FUEL_COM'][f5_z17['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Butylene')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z18['INPUT_HEAT_CAPACITY'][f5_z18['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z18['ENERGY_COM'][f5_z18['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z18['AGGR_HIGH_HEAT_CAPACITY'][f5_z18['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z18['FUEL_COM'][f5_z18['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Naphtha (<401 deg F)')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z19['INPUT_HEAT_CAPACITY'][f5_z19['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z19['ENERGY_COM'][f5_z19['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z19['AGGR_HIGH_HEAT_CAPACITY'][f5_z19['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z19['FUEL_COM'][f5_z19['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Natural Gasoline')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z20['INPUT_HEAT_CAPACITY'][f5_z20['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z20['ENERGY_COM'][f5_z20['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z20['AGGR_HIGH_HEAT_CAPACITY'][f5_z20['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z20['FUEL_COM'][f5_z20['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Other Oil (>401 deg F)')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z21['INPUT_HEAT_CAPACITY'][f5_z21['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z21['ENERGY_COM'][f5_z21['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z21['AGGR_HIGH_HEAT_CAPACITY'][f5_z21['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z21['FUEL_COM'][f5_z21['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Pentanes Plus')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z22['INPUT_HEAT_CAPACITY'][f5_z22['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z22['ENERGY_COM'][f5_z22['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z22['AGGR_HIGH_HEAT_CAPACITY'][f5_z22['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z22['FUEL_COM'][f5_z22['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Petrochemical Feedstocks')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z23['INPUT_HEAT_CAPACITY'][f5_z23['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z23['ENERGY_COM'][f5_z23['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z23['AGGR_HIGH_HEAT_CAPACITY'][f5_z23['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z23['FUEL_COM'][f5_z23['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Special Naphtha')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z24['INPUT_HEAT_CAPACITY'][f5_z24['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z24['ENERGY_COM'][f5_z24['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z24['AGGR_HIGH_HEAT_CAPACITY'][f5_z24['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z24['FUEL_COM'][f5_z24['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Unfinished Oils')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z25['INPUT_HEAT_CAPACITY'][f5_z25['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z25['ENERGY_COM'][f5_z25['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z25['AGGR_HIGH_HEAT_CAPACITY'][f5_z25['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z25['FUEL_COM'][f5_z25['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Heavy Gas Oils')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z26['INPUT_HEAT_CAPACITY'][f5_z26['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z26['ENERGY_COM'][f5_z26['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z26['AGGR_HIGH_HEAT_CAPACITY'][f5_z26['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z26['FUEL_COM'][f5_z26['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Lubricants')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z27_tier1['INPUT_HEAT_CAPACITY'][f5_z27_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z27_tier1['ENERGY_COM'][f5_z27_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z27_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z27_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z27_tier1['FUEL_COM'][f5_z27_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Motor Gasoline')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z28['INPUT_HEAT_CAPACITY'][f5_z28['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z28['ENERGY_COM'][f5_z28['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z28['AGGR_HIGH_HEAT_CAPACITY'][f5_z28['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z28['FUEL_COM'][f5_z28['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Aviation Gasoline')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z29['INPUT_HEAT_CAPACITY'][f5_z29['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z29['ENERGY_COM'][f5_z29['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z29['AGGR_HIGH_HEAT_CAPACITY'][f5_z29['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z29['FUEL_COM'][f5_z29['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Kerosene-Type Jet Fuel')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z30['INPUT_HEAT_CAPACITY'][f5_z30['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z30['ENERGY_COM'][f5_z30['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z30['AGGR_HIGH_HEAT_CAPACITY'][f5_z30['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z30['FUEL_COM'][f5_z30['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Asphalt and Road Oil')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z31['INPUT_HEAT_CAPACITY'][f5_z31['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z31['ENERGY_COM'][f5_z31['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z31['AGGR_HIGH_HEAT_CAPACITY'][f5_z31['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z31['FUEL_COM'][f5_z31['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Crude Oil')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z32['INPUT_HEAT_CAPACITY'][f5_z32['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z32['ENERGY_COM'][f5_z32['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z32['AGGR_HIGH_HEAT_CAPACITY'][f5_z32['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z32['FUEL_COM'][f5_z32['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

ax1.scatter(f5_z33['INPUT_HEAT_CAPACITY'][f5_z33['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z33['ENERGY_COM'][f5_z33['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z33['AGGR_HIGH_HEAT_CAPACITY'][f5_z33['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z33['FUEL_COM'][f5_z33['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Biodiesel')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z34['INPUT_HEAT_CAPACITY'][f5_z34['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z34['ENERGY_COM'][f5_z34['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z34['AGGR_HIGH_HEAT_CAPACITY'][f5_z34['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z34['FUEL_COM'][f5_z34['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Rendered Animal Fat')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z35['INPUT_HEAT_CAPACITY'][f5_z35['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z35['ENERGY_COM'][f5_z35['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z35['AGGR_HIGH_HEAT_CAPACITY'][f5_z35['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z35['FUEL_COM'][f5_z35['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (gallon)')
plt.title('Vegetable Oil')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z37_tier1['INPUT_HEAT_CAPACITY'][f5_z37_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z37_tier1['ENERGY_COM'][f5_z37_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z37_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z37_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z37_tier1['FUEL_COM'][f5_z37_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (scf)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Natural Gas (Weighted U.S. Average')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z38['INPUT_HEAT_CAPACITY'][f5_z38['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z38['ENERGY_COM'][f5_z38['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z38['AGGR_HIGH_HEAT_CAPACITY'][f5_z38['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z38['FUEL_COM'][f5_z38['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (scf)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Propane Gas')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z39['INPUT_HEAT_CAPACITY'][f5_z39['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z39['ENERGY_COM'][f5_z39['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z39['AGGR_HIGH_HEAT_CAPACITY'][f5_z39['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z39['FUEL_COM'][f5_z39['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (scf)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Blast Furnace Gas')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z40['INPUT_HEAT_CAPACITY'][f5_z40['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z40['ENERGY_COM'][f5_z40['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z40['AGGR_HIGH_HEAT_CAPACITY'][f5_z40['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z40['FUEL_COM'][f5_z40['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (scf)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Coke Oven Gas')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z41['INPUT_HEAT_CAPACITY'][f5_z41['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z41['ENERGY_COM'][f5_z41['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z41['AGGR_HIGH_HEAT_CAPACITY'][f5_z41['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z41['FUEL_COM'][f5_z41['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (scf)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Fuel Gas')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z42['INPUT_HEAT_CAPACITY'][f5_z42['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z42['ENERGY_COM'][f5_z42['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z42['AGGR_HIGH_HEAT_CAPACITY'][f5_z42['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z42['FUEL_COM'][f5_z42['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (scf)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Landfill Gas')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z43['INPUT_HEAT_CAPACITY'][f5_z43['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z43['ENERGY_COM'][f5_z43['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z43['AGGR_HIGH_HEAT_CAPACITY'][f5_z43['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z43['FUEL_COM'][f5_z43['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (scf)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Other Biomass Gases')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z44_tier1['INPUT_HEAT_CAPACITY'][f5_z44_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z44_tier1['ENERGY_COM'][f5_z44_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z44_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z44_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z44_tier1['FUEL_COM'][f5_z44_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (scf)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Biogas (Captured methane)')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z45['INPUT_HEAT_CAPACITY'][f5_z45['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z45['ENERGY_COM'][f5_z45['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z45['AGGR_HIGH_HEAT_CAPACITY'][f5_z45['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z45['FUEL_COM'][f5_z45['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Anthracite')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z46['INPUT_HEAT_CAPACITY'][f5_z46['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z46['ENERGY_COM'][f5_z46['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z46['AGGR_HIGH_HEAT_CAPACITY'][f5_z46['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z46['FUEL_COM'][f5_z46['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Bituminous')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z47['INPUT_HEAT_CAPACITY'][f5_z47['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z47['ENERGY_COM'][f5_z47['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z47['AGGR_HIGH_HEAT_CAPACITY'][f5_z47['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z47['FUEL_COM'][f5_z47['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Subbituminous')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z48['INPUT_HEAT_CAPACITY'][f5_z48['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z48['ENERGY_COM'][f5_z48['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z48['AGGR_HIGH_HEAT_CAPACITY'][f5_z48['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z48['FUEL_COM'][f5_z48['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Lignite')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z49['INPUT_HEAT_CAPACITY'][f5_z49['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z49['ENERGY_COM'][f5_z49['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z49['AGGR_HIGH_HEAT_CAPACITY'][f5_z49['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z49['FUEL_COM'][f5_z49['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

ax1.scatter(f5_z63['INPUT_HEAT_CAPACITY'][f5_z63['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z63['ENERGY_COM'][f5_z63['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z63['AGGR_HIGH_HEAT_CAPACITY'][f5_z63['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z63['FUEL_COM'][f5_z63['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Coal Coke')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z50['INPUT_HEAT_CAPACITY'][f5_z50['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z50['ENERGY_COM'][f5_z50['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z50['AGGR_HIGH_HEAT_CAPACITY'][f5_z50['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z50['FUEL_COM'][f5_z50['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Mixed (Commercial sector)')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z51['INPUT_HEAT_CAPACITY'][f5_z51['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z51['ENERGY_COM'][f5_z51['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z51['AGGR_HIGH_HEAT_CAPACITY'][f5_z51['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z51['FUEL_COM'][f5_z51['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Mixed (Industrial coking)')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z52['INPUT_HEAT_CAPACITY'][f5_z52['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z52['ENERGY_COM'][f5_z52['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z52['AGGR_HIGH_HEAT_CAPACITY'][f5_z52['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z52['FUEL_COM'][f5_z52['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Mixed (Industrial sector)')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z53['INPUT_HEAT_CAPACITY'][f5_z53['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z53['ENERGY_COM'][f5_z53['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z53['AGGR_HIGH_HEAT_CAPACITY'][f5_z53['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z53['FUEL_COM'][f5_z53['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Mixed (Electric Power sector)')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z54['INPUT_HEAT_CAPACITY'][f5_z54['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z54['ENERGY_COM'][f5_z54['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z54['AGGR_HIGH_HEAT_CAPACITY'][f5_z54['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z54['FUEL_COM'][f5_z54['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Petroleum Coke')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z55['INPUT_HEAT_CAPACITY'][f5_z55['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z55['ENERGY_COM'][f5_z55['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z55['AGGR_HIGH_HEAT_CAPACITY'][f5_z55['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z55['FUEL_COM'][f5_z55['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Municipal Solid Waste')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z56['INPUT_HEAT_CAPACITY'][f5_z56['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z56['ENERGY_COM'][f5_z56['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z56['AGGR_HIGH_HEAT_CAPACITY'][f5_z56['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z56['FUEL_COM'][f5_z56['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Tires')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z57['INPUT_HEAT_CAPACITY'][f5_z57['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z57['ENERGY_COM'][f5_z57['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z57['AGGR_HIGH_HEAT_CAPACITY'][f5_z57['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z57['FUEL_COM'][f5_z57['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Plastics')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z58_tier1['INPUT_HEAT_CAPACITY'][f5_z58_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z58_tier1['ENERGY_COM'][f5_z58_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z58_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z58_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z58_tier1['FUEL_COM'][f5_z58_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

ax1.scatter(f5_z59_tier1['INPUT_HEAT_CAPACITY'][f5_z59_tier1['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z59_tier1['ENERGY_COM'][f5_z59_tier1['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z59_tier1['AGGR_HIGH_HEAT_CAPACITY'][f5_z59_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z59_tier1['FUEL_COM'][f5_z59_tier1['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Wood and Wood Residuals')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z60['INPUT_HEAT_CAPACITY'][f5_z60['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z60['ENERGY_COM'][f5_z60['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z60['AGGR_HIGH_HEAT_CAPACITY'][f5_z60['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z60['FUEL_COM'][f5_z60['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Agricultural Byproducts')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z61['INPUT_HEAT_CAPACITY'][f5_z61['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z61['ENERGY_COM'][f5_z61['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z61['AGGR_HIGH_HEAT_CAPACITY'][f5_z61['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z61['FUEL_COM'][f5_z61['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Peat')
plt.show()

# %%
#plot fuel usage and capacity
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(f5_z62['INPUT_HEAT_CAPACITY'][f5_z62['INPUT_HEAT_CAPACITY'] != 0]*365.25*24, f5_z62['ENERGY_COM'][f5_z62['INPUT_HEAT_CAPACITY'] != 0], s=10, c='b', marker="s", label='Input heat capacity')
ax1.scatter(f5_z62['AGGR_HIGH_HEAT_CAPACITY'][f5_z62['AGGR_HIGH_HEAT_CAPACITY'] != 0]*365.25*24, f5_z62['FUEL_COM'][f5_z62['AGGR_HIGH_HEAT_CAPACITY'] != 0], s=10, c='r', marker="o", label='Aggregated heat capacity')

plt.legend(loc='upper right')
plt.xlabel('heat capacity (MMBtu/yr)')
plt.ylabel('fuel consumption (ton)')
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Solid Byproducts')
plt.show()
